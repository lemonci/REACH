# %% [markdown]
# # Preparation

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Loading

# %%
# Read source file
rawdata = pd.read_csv('scopus2.csv')

# %%
processeddata = rawdata[rawdata["Author Keywords"].notnull() | rawdata["Index Keywords"].notnull()] #remove null row based on a column

# %%
rawdata.shape
# Out:
# (1512, 41)

# %%
processeddata.shape
# Out:
# (1229, 41)

# %%
processeddata

# %%
processeddata.to_csv('elimitedmissingkeywords.csv')

# %%
processeddata= pd.read_csv('elimitedmissingkeywords.csv')

# %%
processeddata

# %%
#used for output
author = processeddata.iloc[:,1]
title = processeddata.iloc[:,2]
year = processeddata.iloc[:,3]
source = processeddata.iloc[:,4]

#used for label instances
authkey = processeddata.iloc[:,17]
editkey = processeddata.iloc[:,18]

# %% [markdown]
# # Prepare functions

# %%
dictfile=open('USBRDict.txt','r') # open British-American dictionary 

ubdict={} # create an empty dictionary

# Fill dictionary with key:value pairs
for line in dictfile: 
    dictentry = str(line).split(':')
    ubdict[dictentry[0]]=dictentry[1][0:-1]

dictfile.close()    #close the dictionary file
    
#define a british2Amecian converting function

def britishise(keyword): 
    flag = 0
    for word in keyword.split():
        if word in ubdict:
            keyword = re.sub(word,ubdict[word],keyword)
    return keyword

# %%
import inflection #import library for sinuglarise words

# %%
def regularise(word):
    
    
    processedword = re.sub('[\"\']','', word.lower()) # remove ' and " , put everything to lower case
    processedword = re.sub(r'\(.*\)','', processedword) # remove () and everything inside
    processedword = re.sub(' +',' ',processedword) # remove continuous space
    processedword = re.sub('^ +','',processedword) # remove space at the beginning
    processedword = inflection.singularize(processedword) # convert all plural to singlar: Unifying to Singular
    processedword = britishise(processedword) # convert American spelling to british spelling: Unifying to British
    return processedword

# %% [markdown]
# # Convert loading to a list of dictionaries

# %%
dictlist = [] #create an empty list

# %%
#Fill the list with dictionaries
for i in range(0,len(authkey)):
    singledict = {'': 0}
    if authkey[i]:
        for keywordsingle in str(authkey[i]).split(';'):
                        
            processedkeyword = regularise(keywordsingle)
                        
            singledict[processedkeyword] = 1     
            
    if editkey[i]:
        for keywordsingle in str(editkey[i]).split(';'):
                        
            processedkeyword = regularise(keywordsingle)
                        
            singledict[processedkeyword] = 1     
            
    dictlist.append(singledict)

# %%
dictlist
# Out:
# [{'': 0,
#   'accounting and finance': 1,
#   'african american': 1,
#   'college major': 1,
#   'influence factor': 1,
#   'information source': 1,
#   'nan': 1},
#  {'': 0,
#   'complaint management': 1,
#   'goffman': 1,
#   'impression management': 1,
#   'nan': 1,
#   'practical knowing': 1,
#   'teamwork': 1,
#   'trust': 1},
#  {'': 0,
#   'cost of ownership': 1,
#   'management accounting standard': 1,
#   'nan': 1,
#   'semiconductor industry': 1,
#   'standard development history': 1},
#  {'': 0,
#   'commitment': 1,
#   'information management': 1,
#   'knowledge acquisition': 1,
#   'knowledge based system': 1,
#   'knowledge management': 1,
#   'knowledge management system': 1,
#   'knowledge sharing': 1,
#   'knowledge system': 1,
#   'knowledge-sharing': 1,
#   'motivation': 1,
#   'personal information management': 1,
#   'related factor': 1,
#   'research model': 1,
#   'social aspect': 1,
#   'survey': 1,
#   'three component model': 1,
#   'transparency': 1},
#  {'': 0,
#   'accounting': 1,
#   'business model': 1,
#   'nan': 1,
#   'non- reporting': 1,
#   'strategy': 1,
#   'structuration theory': 1},
#  {'': 0,
#   'adult': 1,
#   'article': 1,
#   'body weight loss': 1,
#   'cross-sectional study': 1,
#   'exercise': 1,
#   'female': 1,
#   'functional limitation': 1,
#   'health practitioner': 1,
#   'human': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'nhane': 1,
#   'nutrition': 1,
#   'physical therapy': 1,
#   'physiotherapist': 1,
#   'physiotherapy': 1,
#   'prescription': 1,
#   'prevalence': 1,
#   'public health': 1,
#   'self report': 1,
#   'software': 1,
#   'weight loss': 1},
#  {'': 0,
#   'change': 1,
#   'embedded agency': 1,
#   'identity': 1,
#   'management accounting': 1,
#   'nan': 1},
#  {'': 0,
#   'article': 1,
#   'catalyst': 1,
#   'confirmatory factor analysis': 1,
#   'content validity': 1,
#   'cronbach alpha coefficient': 1,
#   'exploratory factor analysis': 1,
#   'exploratory research': 1,
#   'human': 1,
#   'human experiment': 1,
#   'internal consistency': 1,
#   'interview': 1,
#   'nurse': 1,
#   'oblimin rotation': 1,
#   'perception': 1,
#   'questionnaire': 1,
#   'reliability': 1,
#   'training transfer': 1,
#   'transfer of learning': 1,
#   'validation process': 1,
#   'validity': 1,
#   'workplace': 1},
#  {'': 0,
#   'accounting education': 1,
#   'continuing professional education': 1,
#   'institutionalism': 1,
#   'nan': 1,
#   'professional body': 1},
#  {'': 0,
#   '150 credit-hour requirement': 1,
#   'aaa': 1,
#   'accounting education': 1,
#   'accounting history': 1,
#   'aicpa': 1,
#   'beamer committee': 1,
#   'biography': 1,
#   'continuing education requirement': 1,
#   'cpa license': 1,
#   'elmer g beamer': 1,
#   'haskins & sell': 1,
#   'nan': 1},
#  {'': 0,
#   'audit committee appointment power': 1,
#   'audit firm rotation': 1,
#   'audit firm tendering': 1,
#   'audit firm voluntary selection': 1,
#   'corporate governance': 1,
#   'investment recommendation': 1,
#   'nan': 1},
#  {'': 0,
#   'community attachment': 1,
#   'family': 1,
#   'friend': 1,
#   'job embeddedness': 1,
#   'nan': 1,
#   'relationship': 1,
#   'spillover': 1,
#   'turnover intention': 1,
#   'work–life': 1},
#  {'': 0,
#   'chemoprevention': 1,
#   'cohort study': 1,
#   'hydroxymethylglutaryl-coa reductase inhibitor': 1,
#   'nan': 1,
#   'pancreatic neoplasm': 1,
#   'risk factor': 1},
#  {'': 0,
#   'bis-11': 1,
#   'crt': 1,
#   'decision making': 1,
#   'dual process': 1,
#   'executive function': 1,
#   'impulsivity': 1,
#   'nan': 1,
#   'reasoning process': 1,
#   'reflectivity': 1},
#  {'': 0,
#   'financial reporting': 1,
#   'nan': 1,
#   'new public management': 1,
#   'progressive public administration': 1,
#   'public sector': 1},
#  {'': 0,
#   'accounting curricula': 1,
#   'data analytic': 1,
#   'nan': 1,
#   'professional competency': 1,
#   'survey research': 1},
#  {'': 0,
#   'accountant': 1,
#   'accounting practitioner': 1,
#   'information technology': 1,
#   'maturity': 1,
#   'nan': 1,
#   'practitioner': 1,
#   'skill': 1,
#   'socio technical system': 1},
#  {'': 0,
#   'accountancy profession': 1,
#   'continuing professional development': 1,
#   'nan': 1,
#   'professional accountant': 1,
#   'public interest': 1},
#  {'': 0,
#   'knowledge sharing': 1,
#   'mentoring': 1,
#   'mentoring relationship challenge': 1,
#   'nan': 1,
#   'organizational commitment': 1,
#   'public accounting': 1,
#   'social exchange theory': 1},
#  {'': 0,
#   'accounting profession': 1,
#   'committee on accounting procedure': 1,
#   'knowledge mandate': 1,
#   'nan': 1,
#   'regulatory space': 1,
#   'standard setting': 1},
#  {'': 0,
#   'ceo duality': 1,
#   'family board representation': 1,
#   'financial performance': 1,
#   'football industry': 1,
#   'human capital': 1,
#   'nan': 1},
#  {'': 0,
#   'capacity': 1,
#   'decision-making': 1,
#   'dementium': 1,
#   'involvement': 1,
#   'multidisciplinary team': 1,
#   'nan': 1,
#   'social work': 1},
#  {'': 0,
#   'educational policy': 1,
#   'financial crisis': 1,
#   'nan': 1,
#   'pedagogical department': 1,
#   'teacher training': 1},
#  {'': 0,
#   'conversational case-based reasoning': 1,
#   'diagnosis': 1,
#   'experience management': 1,
#   'nan': 1,
#   'problem solving': 1},
#  {'': 0,
#   'autonomy': 1,
#   'distributed leadership': 1,
#   'job satisfaction': 1,
#   'leadership': 1,
#   'nan': 1,
#   'retention': 1,
#   'teacher': 1},
#  {'': 0,
#   'accounting history': 1,
#   'auditing': 1,
#   'corporate control': 1,
#   'east india company': 1,
#   'governance': 1,
#   'nan': 1},
#  {'': 0,
#   'article': 1,
#   'control system': 1,
#   'diagnosis': 1,
#   'diagnostic accuracy': 1,
#   'diagnostic error': 1,
#   'field assessment': 1,
#   'health care personnel': 1,
#   'human': 1,
#   'nonhuman': 1,
#   'parasite control': 1,
#   'parasite transmission': 1,
#   'quality control': 1,
#   'schistosoma japonicum': 1,
#   'schistosomiasi': 1,
#   'standard': 1,
#   'stool hatching method': 1,
#   'technical and domestic health care assistance': 1,
#   'worm egg': 1},
#  {'': 0,
#   'dental implant': 1,
#   'laser-microgrooved collar surface': 1,
#   'nan': 1,
#   'peri-implant mucositi': 1,
#   'peri-implantiti': 1,
#   'prevalence': 1},
#  {'': 0,
#   'accessibility': 1,
#   'algorithm': 1,
#   'e2sfca algorithm': 1,
#   'edge effect': 1,
#   'france': 1,
#   'geographic information system': 1,
#   'gi': 1,
#   'health care': 1,
#   'health service': 1,
#   'potential spatial accessibility of healthcare professional': 1,
#   'pregnancy': 1,
#   'pregnant woman': 1,
#   'spatial analysis': 1},
#  {'': 0,
#   'calculative culture': 1,
#   'enterprise risk management': 1,
#   'information quality': 1,
#   'managerial accounting': 1,
#   'nan': 1,
#   'reporting': 1,
#   'risk quantification': 1},
#  {'': 0,
#   'independence': 1,
#   'internal audit': 1,
#   'nan': 1,
#   'professionalism': 1},
#  {'': 0,
#   'adverse outcome': 1,
#   'aged': 1,
#   'arthroplasty, replacement, shoulder': 1,
#   'clinical decision making': 1,
#   'clinical decision-making': 1,
#   'comparative study': 1,
#   'conference paper': 1,
#   'data mining': 1,
#   'databases, factual': 1,
#   'decision support system': 1,
#   'decision support technique': 1,
#   'diagnostic imaging': 1,
#   'evidence based medicine': 1,
#   'evidence-based medicine': 1,
#   'factual database': 1,
#   'female': 1,
#   'frozen shoulder': 1,
#   'health care quality': 1,
#   'hospital discharge': 1,
#   'hospital readmission': 1,
#   'human': 1,
#   'logistic model': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'middle aged': 1,
#   'nan': 1,
#   'odds ratio': 1,
#   'operation duration': 1,
#   'orthopedic surgeon': 1,
#   'pathophysiology': 1,
#   'patient readmission': 1,
#   'perioperative period': 1,
#   'practise gap': 1,
#   'predictive value': 1,
#   'predictive value of test': 1,
#   'preoperative evaluation': 1,
#   'priority journal': 1,
#   'process assessment ': 1,
#   'professional practise gap': 1,
#   'risk assessment': 1,
#   'risk factor': 1,
#   'shoulder': 1,
#   'shoulder arthriti': 1,
#   'shoulder joint': 1,
#   'shoulder pain': 1,
#   'shoulder replacement': 1,
#   'statistical model': 1,
#   'surgery': 1,
#   'surgical clearance': 1,
#   'time factor': 1,
#   'total shoulder arthroplasty': 1,
#   'treatment outcome': 1,
#   'urea nitrogen blood level': 1},
#  {'': 0,
#   'chartered accountants ireland': 1,
#   'continuing professional development': 1,
#   'nan': 1,
#   'professional competence': 1,
#   'professional practise': 1},
#  {'': 0,
#   'accounting education': 1,
#   'accreditation': 1,
#   'liberal education': 1,
#   'nan': 1,
#   'professional accountancy body': 1,
#   'uk accounting degree': 1},
#  {'': 0,
#   'accreditation': 1,
#   'identity of academic': 1,
#   'nan': 1,
#   'pathways commission': 1,
#   'professional accountancy body': 1,
#   'uk accounting degree': 1},
#  {'': 0,
#   'big datum': 1,
#   'budget': 1,
#   'budget control': 1,
#   'certification': 1,
#   'chief audit executive': 1,
#   'data analytic': 1,
#   'descriptive information': 1,
#   'education': 1,
#   'government': 1,
#   'human': 1,
#   'human experiment': 1,
#   'information system': 1,
#   'internal audit': 1,
#   'internal audit function': 1,
#   'interview': 1,
#   'large amounts of datum': 1,
#   'non profit organization': 1,
#   'not-for-profit organization': 1,
#   'perception': 1,
#   'professional certification': 1,
#   'profitability': 1,
#   'student': 1,
#   'workplace': 1},
#  {'': 0,
#   'accounting talk': 1,
#   'compliance': 1,
#   'concurrent visibility': 1,
#   'healthcare': 1,
#   'ideological control': 1,
#   'nan': 1,
#   'non-governmental organization': 1,
#   'organizational identity': 1},
#  {'': 0,
#   'access to information': 1,
#   'article': 1,
#   'cardiology': 1,
#   'ehealth': 1,
#   'health care organization': 1,
#   'heart failure': 1,
#   'heartfailurematters.org': 1,
#   'human': 1,
#   'internet': 1,
#   'online system': 1,
#   'patient education': 1,
#   'priority journal': 1,
#   'search engine': 1,
#   'software design': 1,
#   'website': 1},
#  {'': 0,
#   'adult': 1,
#   'barrier': 1,
#   'british columbium': 1,
#   'canada': 1,
#   'child': 1,
#   'content analysis': 1,
#   'exercise': 1,
#   'extraction': 1,
#   'facilitator': 1,
#   'female': 1,
#   'genetic transcription': 1,
#   'health care policy': 1,
#   'health policy': 1,
#   'human': 1,
#   'identity': 1,
#   'implementation': 1,
#   'interview': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'middle aged': 1,
#   'organization and management': 1,
#   'outcome assessment': 1,
#   'physical activity': 1,
#   'policy': 1,
#   'professional standard': 1,
#   'psychological theory': 1,
#   'psychology': 1,
#   'qualitative research': 1,
#   'school': 1,
#   'school health service': 1,
#   'school teacher': 1,
#   'scientist': 1,
#   'statistics and numerical datum': 1,
#   'student': 1,
#   'teacher': 1,
#   'theoretical domains framework': 1,
#   'theoretical study': 1},
#  {'': 0,
#   'account management system': 1,
#   'law firm': 1,
#   'malaysium': 1,
#   'nan': 1},
#  {'': 0,
#   'econometric': 1,
#   'economic': 1,
#   'economic analysis': 1,
#   'information security': 1,
#   'information security investment': 1,
#   'information security professional': 1,
#   'information security risk': 1,
#   'information system': 1,
#   'investment': 1,
#   'managerial risk': 1,
#   'managerial risk accounting': 1,
#   'return on security investment': 1,
#   'security investment': 1,
#   'security of datum': 1,
#   'statistic': 1,
#   'systematic literature review': 1,
#   'technological aspect': 1},
#  {'': 0,
#   'adult': 1,
#   'age': 1,
#   'age factor': 1,
#   'behaviour': 1,
#   'career': 1,
#   'climate': 1,
#   'communication': 1,
#   'congresses as topic': 1,
#   'education': 1,
#   'female': 1,
#   'human': 1,
#   'human experiment': 1,
#   'interpersonal communication': 1,
#   'male': 1,
#   'nan': 1,
#   'organization': 1,
#   'personnel': 1,
#   'psychology': 1,
#   'research personnel': 1,
#   'scientist': 1,
#   'sex characteristic': 1,
#   'sex difference': 1,
#   'sexism': 1,
#   'sexual development': 1,
#   'statistics and numerical datum': 1},
#  {'': 0,
#   'academic medical centre': 1,
#   'adult': 1,
#   'article': 1,
#   'asian': 1,
#   'awards and prize': 1,
#   'biomedical research': 1,
#   'caucasian': 1,
#   'economic': 1,
#   'faculty, medical': 1,
#   'fellowships and scholarship': 1,
#   'female': 1,
#   'financial management': 1,
#   'financing, government': 1,
#   'full time employment': 1,
#   'gender': 1,
#   'human': 1,
#   'male': 1,
#   'manpower': 1,
#   'medical education': 1,
#   'medical research': 1,
#   'medical school': 1,
#   'medicine': 1,
#   'mentor': 1,
#   'middle aged': 1,
#   'national health organization': 1,
#   'national institutes of health ': 1,
#   'neurology': 1,
#   'nih grant': 1,
#   'pacific islander': 1,
#   'paediatric': 1,
#   'parttime employment': 1,
#   'pathology': 1,
#   'personnel': 1,
#   'priority journal': 1,
#   'productivity': 1,
#   'psychiatry': 1,
#   'publication': 1,
#   'r01': 1,
#   'radiology': 1,
#   'research personnel': 1,
#   'research support as topic': 1,
#   'schools, medical': 1,
#   'sex difference': 1,
#   'sex factor': 1,
#   'statistics and numerical datum': 1,
#   'surgery': 1,
#   'united state': 1,
#   'university hospital': 1},
#  {'': 0,
#   'annual report.': 1,
#   'bangladesh': 1,
#   'bangladesh bank.': 1,
#   'banking': 1,
#   'climate change': 1,
#   'climate change.': 1,
#   'dhaka [bangladesh]': 1,
#   'disclosure.': 1,
#   'environmental accounting.': 1,
#   'environmental assessment': 1,
#   'environmental monitoring': 1,
#   'financial provision': 1,
#   'information': 1,
#   'policy making': 1,
#   'project financing': 1,
#   'project management': 1,
#   'stock market': 1},
#  {'': 0,
#   'assessment': 1,
#   'decision making': 1,
#   'journal ranking': 1,
#   'nan': 1},
#  {'': 0,
#   'auditing': 1,
#   'automation': 1,
#   'big datum': 1,
#   'data analytic': 1,
#   'financial accounting': 1,
#   'management accounting': 1,
#   'nan': 1},
#  {'': 0,
#   'academic disciplines and tradition': 1,
#   'accounting practise': 1,
#   'governance': 1,
#   'nan': 1,
#   'politic': 1,
#   'power': 1,
#   'representation': 1},
#  {'': 0,
#   'accounting firm': 1,
#   'bring your own device': 1,
#   'byod': 1,
#   'education': 1,
#   'learning experience': 1,
#   'management of information technology': 1,
#   'practical experience': 1,
#   'real-world': 1,
#   'student': 1,
#   'teaching': 1,
#   'teaching case study': 1},
#  {'': 0,
#   'budget control': 1,
#   'cost benefit analysis': 1,
#   'cost estimating': 1,
#   'design professional': 1,
#   'e-mail address': 1,
#   'estimation tool': 1,
#   'intranet portal': 1,
#   'lense': 1,
#   'nan': 1,
#   'project accounting': 1,
#   'skilled labor': 1,
#   'traditional value': 1,
#   'virtual modeling': 1},
#  {'': 0,
#   'audit quality': 1,
#   'big 4 auditor': 1,
#   'cost of equity capital': 1,
#   'earnings management': 1,
#   'emerging economy': 1,
#   'indian stock market': 1,
#   'nan': 1},
#  {'': 0,
#   'algorithm': 1,
#   'biological marker': 1,
#   'biomedical technology assessment': 1,
#   'clinical audit': 1,
#   'clinical laboratory': 1,
#   'clinical laboratory technique': 1,
#   'clinical pathway': 1,
#   'computerised provider order entry': 1,
#   'cooperation': 1,
#   'cost': 1,
#   'cost control': 1,
#   'cost effectiveness analysis': 1,
#   'costs and cost analysis': 1,
#   'diagnostic accuracy': 1,
#   'economic': 1,
#   'electronic medical record system': 1,
#   'human': 1,
#   'laboratory personnel': 1,
#   'laboratory technique': 1,
#   'laboratory test': 1,
#   'medical records systems, computerised': 1,
#   'monitoring': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'practise guideline': 1,
#   'practise guidelines as topic': 1,
#   'prevalence': 1,
#   'priority journal': 1,
#   'review': 1,
#   'standard': 1,
#   'treatment outcome': 1},
#  {'': 0,
#   'acquired immune deficiency syndrome': 1,
#   'advocacy group': 1,
#   'anti-retroviral agent': 1,
#   'antiretroviral market': 1,
#   'antiretroviral therapy': 1,
#   'antiretrovirus agent': 1,
#   'drug industry': 1,
#   'economic': 1,
#   'emergency care': 1,
#   'government': 1,
#   'government programme': 1,
#   'health care delivery': 1,
#   'health services accessibility': 1,
#   'hiv infection': 1,
#   'human': 1,
#   'human immunodeficiency virus': 1,
#   'human immunodeficiency virus infection': 1,
#   'introduction of new antiretroviral': 1,
#   'manpower': 1,
#   'marketing': 1,
#   'personal experience': 1,
#   'priority journal': 1,
#   'professionalism': 1,
#   'review': 1,
#   'supply and distribution': 1,
#   'supply chain': 1,
#   'treatment planning': 1,
#   'who treatment guideline': 1,
#   'world health organization': 1},
#  {'': 0,
#   'anecdotal evidence': 1,
#   'business structure': 1,
#   'competition': 1,
#   'education': 1,
#   'engineering discipline': 1,
#   'engineering education': 1,
#   'engineering leadership': 1,
#   'experiential learning': 1,
#   'leadership development': 1,
#   'nan': 1,
#   'pedagogical approach': 1,
#   'professional engineering': 1,
#   'student': 1,
#   'sustainable development': 1},
#  {'': 0,
#   'accounting professionalisation': 1,
#   'actor-network theory': 1,
#   'hybridity': 1,
#   'nan': 1,
#   'state corporatism': 1},
#  {'': 0,
#   'business partner': 1,
#   'critical competence': 1,
#   'external role': 1,
#   'institutional domination': 1,
#   'management accountant': 1,
#   'nan': 1,
#   'popular culture': 1},
#  {'': 0,
#   'chartered professional accountant': 1,
#   'merger': 1,
#   'nan': 1,
#   'social capital': 1,
#   'social network analysis': 1},
#  {'': 0,
#   'corporate governance': 1,
#   'firm performance': 1,
#   'nan': 1,
#   'political connexion': 1},
#  {'': 0,
#   'adult': 1,
#   'affect': 1,
#   'age': 1,
#   'aged': 1,
#   'aggression': 1,
#   'agitation': 1,
#   'alcohol related dementium': 1,
#   'alzheimer disease': 1,
#   'anticonvulsive agent': 1,
#   'antidepressant agent': 1,
#   'anxiolytic agent': 1,
#   'apathy': 1,
#   'article': 1,
#   'caregiver': 1,
#   'comfort': 1,
#   'cross-sectional study': 1,
#   'dementium': 1,
#   'dependent variable': 1,
#   'depression': 1,
#   'diffuse lewy body disease': 1,
#   'disease association': 1,
#   'disease severity': 1,
#   'drug use': 1,
#   'emotion': 1,
#   'female': 1,
#   'frontotemporal dementium': 1,
#   'gender': 1,
#   'gerontopsychiatry': 1,
#   'human': 1,
#   'hypnotic agent': 1,
#   'independent variable': 1,
#   'length of stay': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'mental disease': 1,
#   'multicenter study ': 1,
#   'multiinfarct dementium': 1,
#   'multilevel analysis': 1,
#   'neuroleptic agent': 1,
#   'neuropsychiatric symptom': 1,
#   'neurosyphili': 1,
#   'nootropic agent': 1,
#   'nursing home': 1,
#   'nursing home patient': 1,
#   'parkinson disease': 1,
#   'priority journal': 1,
#   'psychopharmacotherapy': 1,
#   'psychosi': 1,
#   'psychotropic agent': 1,
#   'psychotropic drug': 1,
#   'quality of life': 1,
#   'quality of life assessment': 1,
#   'quality of life in dementia questionnaire': 1,
#   'restlessness': 1,
#   'sedative agent': 1,
#   'self concept': 1,
#   'social determinants of health': 1,
#   'social interaction': 1,
#   'social isolation': 1,
#   'young onset dementium': 1,
#   'young-onset dementium': 1},
#  {'': 0,
#   'adult': 1,
#   'aged': 1,
#   'ambulatory care': 1,
#   'antipsychotic': 1,
#   'article': 1,
#   'family': 1,
#   'female': 1,
#   'general practise': 1,
#   'government': 1,
#   'health care organization': 1,
#   'health care quality': 1,
#   'health service research': 1,
#   'human': 1,
#   'italy': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'mental health': 1,
#   'patient monitoring': 1,
#   'practise guideline': 1,
#   'prophylaxi': 1,
#   'psychosocial rehabilitation': 1,
#   'quality indicator': 1,
#   'quality of care schizophrenium': 1,
#   'schizophrenium': 1,
#   'work': 1},
#  {'': 0,
#   'adult': 1,
#   'articular cartilage': 1,
#   'asymptomatic disease': 1,
#   'baseball': 1,
#   'cartilage, articular': 1,
#   'collateral ligament, ulnar': 1,
#   'diagnostic imaging': 1,
#   'elbow': 1,
#   'elbow joint': 1,
#   'human': 1,
#   'injury': 1,
#   'magnetic resonance imaging': 1,
#   'mri': 1,
#   'nuclear magnetic resonance imaging': 1,
#   'osteophyte': 1,
#   'pathology': 1,
#   'pitcher': 1,
#   'professional baseball': 1,
#   'retrospective study': 1,
#   'risk factor': 1,
#   'tendon': 1,
#   'tendon injury': 1,
#   'ulnar collateral ligament': 1,
#   'young adult': 1},
#  {'': 0,
#   'etiquette': 1,
#   'nan': 1,
#   'professional discipline': 1,
#   'professional ethic': 1,
#   'professionalisation': 1},
#  {'': 0,
#   'earnings management': 1,
#   'ethical awareness': 1,
#   'ethical sensitivity': 1,
#   'nan': 1,
#   'professional identity': 1,
#   'professionalism': 1,
#   'rewards structure': 1},
#  {'': 0,
#   'aerodigestive clinic': 1,
#   'article': 1,
#   'child': 1,
#   'clinic revenue': 1,
#   'cohort analysis': 1,
#   'cost benefit analysis': 1,
#   'cost-benefit analysis': 1,
#   'digestive system disease': 1,
#   'economic': 1,
#   'endoscopy': 1,
#   'feasibility study': 1,
#   'follow up': 1,
#   'health care cost': 1,
#   'hospital charge': 1,
#   'human': 1,
#   'laryngoscopy': 1,
#   'major clinical study': 1,
#   'medicaid': 1,
#   'multidisciplinary clinic': 1,
#   'nasopharyngeal endoscopy': 1,
#   'organization and management': 1,
#   'paediatric': 1,
#   'paediatric hospital': 1,
#   'paediatric multidisciplinary aerodigestive clinic': 1,
#   'patient care': 1,
#   'patient care team': 1,
#   'physician income': 1,
#   'priority journal': 1,
#   'procedure': 1,
#   'reimbursement': 1,
#   'respiratory tract disease': 1,
#   'retrospective study': 1,
#   'salary': 1,
#   'statistics and numerical datum': 1,
#   'tertiary care centre': 1,
#   'united state': 1,
#   'value based care': 1},
#  {'': 0,
#   'accounting profession': 1,
#   'adam smith': 1,
#   'code of professional conduct': 1,
#   'conceptual framework': 1,
#   'emmanuel lévina': 1,
#   'nan': 1,
#   'safeguard': 1,
#   'threat': 1,
#   'virtue ethic': 1},
#  {'': 0,
#   'bourdieu': 1,
#   'elite reproduction': 1,
#   'nan': 1,
#   'professional service firm': 1,
#   'social exclusion': 1,
#   'social stratification': 1},
#  {'': 0, 'accounting profession': 1, 'ethic': 1, 'genme': 1, 'nan': 1},
#  {'': 0,
#   'audit report': 1,
#   'ifr': 1,
#   'materiality': 1,
#   'nan': 1,
#   'true and fair view': 1},
#  {'': 0,
#   'cost accounting': 1,
#   'environmental cost': 1,
#   'environmental protection measure': 1,
#   'nan': 1,
#   'payment': 1,
#   'valuation provision': 1},
#  {'': 0,
#   'board leadership structure': 1,
#   'cio reporting structure': 1,
#   'it governance': 1,
#   'it risk management': 1,
#   'nan': 1,
#   'scale development': 1},
#  {'': 0,
#   'academic cardiology': 1,
#   'adult': 1,
#   'aged': 1,
#   'article': 1,
#   'cardiologist': 1,
#   'faculty, medical': 1,
#   'female': 1,
#   'human': 1,
#   'male': 1,
#   'medical education': 1,
#   'medical research': 1,
#   'medical school': 1,
#   'medicare': 1,
#   'middle aged': 1,
#   'national health organization': 1,
#   'policy making': 1,
#   'priority journal': 1,
#   'productivity': 1,
#   'professional development': 1,
#   'publication': 1,
#   'reimbursement': 1,
#   'sex difference': 1,
#   'sex factor': 1,
#   'trend': 1,
#   'united state': 1,
#   'woman': 1,
#   'workforce': 1},
#  {'': 0,
#   'auditor behaviour': 1,
#   'auditor-in-charge involvement': 1,
#   'cross-national cultural difference': 1,
#   'international auditing': 1,
#   'nan': 1,
#   'national culture': 1},
#  {'': 0,
#   'adult': 1,
#   'article': 1,
#   'budget': 1,
#   'budgetary participation': 1,
#   'controlled study': 1,
#   'coping behaviour': 1,
#   'decision making': 1,
#   'economics, hospital': 1,
#   'expectation': 1,
#   'exploratory factor analysis': 1,
#   'female': 1,
#   'goal attainment': 1,
#   'health economic': 1,
#   'human': 1,
#   'information dissemination': 1,
#   'interpersonal communication': 1,
#   'italy': 1,
#   'job performance': 1,
#   'job satisfaction': 1,
#   'male': 1,
#   'manager': 1,
#   'managerial': 1,
#   'mental health': 1,
#   'motivation': 1,
#   'performance': 1,
#   'physician attitude': 1,
#   'professional knowledge': 1,
#   'questionnaire': 1,
#   'role clarity': 1,
#   'self concept': 1,
#   'self efficacy': 1,
#   'self evaluation': 1,
#   'self-efficacy': 1,
#   'surveys and questionnaire': 1,
#   'work experience': 1},
#  {'': 0,
#   'attitude of health personnel': 1,
#   'child': 1,
#   'family': 1,
#   'health personnel attitude': 1,
#   'human': 1,
#   'human relation': 1,
#   'intensive care units, paediatric': 1,
#   'nan': 1,
#   'oregon': 1,
#   'organization and management': 1,
#   'paediatric intensive care unit': 1,
#   'procedure': 1,
#   'professional-family relation': 1,
#   'psychology': 1,
#   'quality improvement': 1,
#   'teaching round': 1,
#   'time factor': 1,
#   'time management': 1,
#   'total quality management': 1,
#   'workflow': 1},
#  {'': 0,
#   'adult': 1,
#   'aged': 1,
#   'antidiabetic agent': 1,
#   'anxiety': 1,
#   'article': 1,
#   'chemically induced': 1,
#   'clinical article': 1,
#   'confidence': 1,
#   'construct validity': 1,
#   'diabetes mellitus, type 1': 1,
#   'diabetes mellitus, type 2': 1,
#   'distress syndrome': 1,
#   'fear': 1,
#   'female': 1,
#   'glycemic control': 1,
#   'health care personnel': 1,
#   'human': 1,
#   'hypoglycemic agent': 1,
#   'hypoglycemium': 1,
#   'insulin': 1,
#   'insulin dependent diabetes mellitu': 1,
#   'male': 1,
#   'middle aged': 1,
#   'non insulin dependent diabetes mellitu': 1,
#   'priority journal': 1,
#   'psychology': 1,
#   'self report': 1,
#   'social psychology': 1,
#   'type 1 diabete': 1,
#   'type 2 diabete': 1,
#   'wellbeing': 1},
#  {'': 0,
#   'adult': 1,
#   'age': 1,
#   'article': 1,
#   'drug cost': 1,
#   'drug induced disease': 1,
#   'drug monitoring': 1,
#   'drug overdose': 1,
#   'drug safety': 1,
#   'drug underdose': 1,
#   'drug-related side effects and adverse reaction': 1,
#   'employment status': 1,
#   'female': 1,
#   'graft recipient': 1,
#   'health status': 1,
#   'high risk patient': 1,
#   'hospital pharmacy': 1,
#   'human': 1,
#   'kidney graft': 1,
#   'kidney transplantation': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'medicaid': 1,
#   'medication adherence': 1,
#   'medication compliance': 1,
#   'medication error': 1,
#   'middle aged': 1,
#   'models, statistical': 1,
#   'observational study': 1,
#   'organization and management': 1,
#   'outcome': 1,
#   'patient education': 1,
#   'pharmacist': 1,
#   'pharmacy practise': 1,
#   'pharmacy service, hospital': 1,
#   'prediction': 1,
#   'professional role': 1,
#   'professional standard': 1,
#   'prospective study': 1,
#   'quality of life': 1,
#   'receiver operating characteristic': 1,
#   'renal': 1,
#   'risk assessment': 1,
#   'sensitivity and specificity': 1,
#   'statistical model': 1,
#   'statistics and numerical datum': 1,
#   'tertiary care centre': 1,
#   'transplant': 1,
#   'transplant recipient': 1,
#   'treatment refusal': 1,
#   'workflow': 1},
#  {'': 0,
#   'ceneval': 1,
#   'computer programming': 1,
#   'computer science': 1,
#   'computing': 1,
#   'egel-info': 1,
#   'electronics engineering': 1,
#   'electronics industry': 1,
#   'evaluation': 1,
#   'graduate': 1},
#  {'': 0,
#   'adult': 1,
#   'article': 1,
#   'attitude to health': 1,
#   'automated external defibrillator': 1,
#   'cardiopulmonary resuscitation': 1,
#   'controlled study': 1,
#   'defibrillator': 1,
#   'denmark': 1,
#   'education': 1,
#   'female': 1,
#   'focus group': 1,
#   'health care access': 1,
#   'health care disparity': 1,
#   'health care distribution': 1,
#   'health care planning': 1,
#   'health knowledge, attitudes, practise': 1,
#   'high school': 1,
#   'human': 1,
#   'implementation': 1,
#   'information processing': 1,
#   'interview': 1,
#   'interviews as topic': 1,
#   'male': 1,
#   'medical education': 1,
#   'middle aged': 1,
#   'nonmedical occupation': 1,
#   'organization and management': 1,
#   'out of hospital cardiac arrest': 1,
#   'out-of-hospital cardiac arrest': 1,
#   'procedure': 1,
#   'psychology': 1,
#   'qualitative research': 1,
#   'resuscitation': 1,
#   'school': 1,
#   'school leader': 1,
#   'school teacher': 1,
#   'semi structured interview': 1,
#   'standard': 1,
#   'statistics and numerical datum': 1,
#   'supply and distribution': 1,
#   'teacher training': 1,
#   'technology acceptance model': 1,
#   'training': 1,
#   'utilization': 1},
#  {'': 0,
#   'accounting community of practise': 1,
#   'accounting education': 1,
#   'communal learning': 1,
#   'cooperative learning': 1,
#   'nan': 1,
#   'social learning theory': 1},
#  {'': 0,
#   '150-hour requirement': 1,
#   'african american cpa': 1,
#   'hispanic cpa': 1,
#   'minority cpa': 1,
#   'nan': 1,
#   'the cpa credential': 1},
#  {'': 0,
#   'adult': 1,
#   'ancestry group': 1,
#   'collaborative competence': 1,
#   'communication': 1,
#   'concurrent validity': 1,
#   'content validity': 1,
#   'continental population group': 1,
#   'controlled study': 1,
#   'cooperation': 1,
#   'cooperative behaviour': 1,
#   'education': 1,
#   'effect size': 1,
#   'evaluation research': 1,
#   'exploratory factor analysis': 1,
#   'factor analysis': 1,
#   'factor analysis, statistical': 1,
#   'female': 1,
#   'health student': 1,
#   'human': 1,
#   'interpersonal communication': 1,
#   'interprofessional education': 1,
#   'interprofessional relation': 1,
#   'item total correlation': 1,
#   'licensing': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'mental capacity': 1,
#   'negotiating': 1,
#   'occupation': 1,
#   'organization and management': 1,
#   'patient care': 1,
#   'patient care team': 1,
#   'patient-centered care': 1,
#   'principal component analysis': 1,
#   'professional competence': 1,
#   'psychology': 1,
#   'public relation': 1,
#   'quantitative analysis': 1,
#   'quantitative method': 1,
#   'questionnaire': 1,
#   'reproducibility': 1,
#   'reproducibility of result': 1,
#   'retrospective study': 1,
#   'self report': 1,
#   'standard': 1,
#   'student': 1,
#   'student assessment': 1,
#   'students, health occupation': 1,
#   'surveys and questionnaire': 1,
#   'validation process': 1,
#   'validation study': 1,
#   'young adult': 1},
#  {'': 0,
#   'aaoifi standard': 1,
#   'basic knowledge': 1,
#   'islamic accounting': 1,
#   'nan': 1,
#   'training': 1,
#   'tunisian accountant': 1},
#  {'': 0,
#   'aaoifi fa': 1,
#   'compliance': 1,
#   'determinant': 1,
#   'ifrs 7': 1,
#   'islamic bank': 1,
#   'nan': 1},
#  {'': 0,
#   'accountability': 1,
#   'financial reporting': 1,
#   'institutional theory': 1,
#   'nan': 1,
#   'regulation': 1},
#  {'': 0,
#   'internal auditor': 1,
#   'job satisfaction': 1,
#   'nan': 1,
#   'staff retention': 1,
#   'turnover': 1},
#  {'': 0,
#   'accounting': 1,
#   'integrated reporting': 1,
#   'integrated thinking': 1,
#   'nan': 1,
#   'sustainability': 1},
#  {'': 0,
#   'accountant': 1,
#   'accounting ethic': 1,
#   'code of ethics for professional accountant': 1,
#   'nan': 1,
#   'professional conduct': 1,
#   'ukraine': 1},
#  {'': 0,
#   'development': 1,
#   'management accounting standard': 1,
#   'methodology': 1,
#   'nan': 1,
#   'recommendation': 1,
#   'regulation': 1},
#  {'': 0, 'accounting': 1, 'forensic': 1, 'nan': 1},
#  {'': 0,
#   'corruption': 1,
#   'international public sector accounting standard': 1,
#   'nan': 1,
#   'patron/clientelism': 1,
#   'wealth redistribution': 1,
#   'western accounting reform': 1},
#  {'': 0,
#   'accounting profession': 1,
#   'actor network theory': 1,
#   'knowledge base': 1,
#   'multiple histories approach': 1,
#   'nan': 1,
#   'regulation': 1,
#   'university': 1},
#  {'': 0,
#   'accounting education': 1,
#   'case study': 1,
#   'case-study': 1,
#   'curricula': 1,
#   'distance education': 1,
#   'e-learning': 1,
#   'education': 1,
#   'geographical dispersion': 1,
#   'learning management system': 1,
#   'open distance learning': 1,
#   'open distance learning ': 1,
#   'research approach': 1,
#   'skills development': 1,
#   'societies and institution': 1,
#   'student': 1,
#   'student number': 1,
#   'survey': 1,
#   'vocational skill': 1},
#  {'': 0,
#   'conformity': 1,
#   'excellence': 1,
#   'nan': 1,
#   'professional body': 1,
#   'quality': 1,
#   'quality class': 1,
#   'quality standard': 1},
#  {'': 0,
#   'accounting student': 1,
#   'competency': 1,
#   'contribution': 1,
#   'higher education institutions information': 1,
#   'information technology': 1,
#   'nan': 1},
#  {'': 0,
#   'accounting information': 1,
#   'agribusiness': 1,
#   'intellectual capital': 1,
#   'nan': 1},
#  {'': 0,
#   'accounting education': 1,
#   'employer expectation': 1,
#   'graduate skill': 1,
#   'language analysis': 1,
#   'learning outcome': 1,
#   'nan': 1},
#  {'': 0,
#   'career development': 1,
#   'career interest': 1,
#   'career management': 1,
#   'career path': 1,
#   'career planning': 1,
#   'nan': 1},
#  {'': 0,
#   'ethics education': 1,
#   'malaysian accounting ethic': 1,
#   'nan': 1,
#   'self-efficacy': 1},
#  {'': 0,
#   'accounting change': 1,
#   'cost calculation': 1,
#   'management accounting': 1,
#   'nan': 1,
#   'romanium': 1},
#  {'': 0,
#   'accounting effect': 1,
#   'everyday life': 1,
#   'financial edutainment': 1,
#   'interpretation': 1,
#   'nan': 1,
#   're-presentation': 1,
#   'signifying practise': 1},
#  {'': 0,
#   'accountant': 1,
#   'accounting manipulation': 1,
#   'ethic': 1,
#   'ethical dilemma': 1,
#   'ethical perception': 1,
#   'external accounting service provider': 1,
#   'nan': 1},
#  {'': 0,
#   'nan': 1,
#   'organic certification': 1,
#   'professional association': 1,
#   'regulatory intermediary': 1},
#  {'': 0,
#   'big datum': 1,
#   'cloud computing': 1,
#   'economic': 1,
#   'economic environment': 1,
#   'education': 1,
#   'emerging information technology': 1,
#   'empirical research': 1,
#   'information management': 1,
#   'information security': 1,
#   'information technologies in accounting': 1,
#   'innovation': 1,
#   'it skill': 1,
#   'regional planning': 1,
#   'romanian university': 1,
#   'romanium': 1,
#   'security of datum': 1,
#   'societies and institution': 1,
#   'sustainable development': 1},
#  {'': 0, 'ifrs research': 1, 'nan': 1, 'paradigm': 1, 'research framework': 1},
#  {'': 0,
#   'active learning assessment': 1,
#   'e-portfolio': 1,
#   'indigenous business education': 1,
#   'nan': 1},
#  {'': 0,
#   'challenge': 1,
#   'convergence': 1,
#   'iasb': 1,
#   'ifrs adoption': 1,
#   'indium': 1,
#   'nan': 1},
#  {'': 0,
#   'accounting firm': 1,
#   'control': 1,
#   'nan': 1,
#   'reputational risk': 1,
#   'risk management': 1,
#   'social medium': 1},
#  {'': 0,
#   'accounting narrative': 1,
#   'cross-cultural research': 1,
#   'interdependent/collectivist culture': 1,
#   'investor judgment and decision making': 1,
#   'linguistic category model ': 1,
#   'nan': 1},
#  {'': 0,
#   'ai': 1,
#   'ethic': 1,
#   'nan': 1,
#   'professionalism': 1,
#   'systemic control': 1,
#   'trust protection': 1,
#   'virtue': 1},
#  {'': 0,
#   'management accounting service quality': 1,
#   'nan': 1,
#   'servqual, servperf': 1},
#  {'': 0,
#   'expectation': 1,
#   'nan': 1,
#   'psychological contract': 1,
#   'qualitative': 1,
#   'reciprocity': 1,
#   'social exchange': 1,
#   'trainee programme': 1},
#  {'': 0,
#   'accounting career': 1,
#   'auditing': 1,
#   'auditor stereotype': 1,
#   'expectation gap': 1,
#   'nan': 1,
#   'real business cases training': 1,
#   'students’ perception': 1},
#  {'': 0,
#   'competency': 1,
#   'fraud': 1,
#   'fraud detection': 1,
#   'internal auditor': 1,
#   'nan': 1,
#   'whistleblowing': 1},
#  {'': 0,
#   'cobit 5': 1,
#   'cognitive dissonance': 1,
#   'core skill': 1,
#   'critical thinking': 1,
#   'nan': 1,
#   'problem solving': 1},
#  {'': 0,
#   'austrium': 1,
#   'career': 1,
#   'enabling factor': 1,
#   'gender': 1,
#   'management accounting': 1,
#   'nan': 1,
#   'woman': 1},
#  {'': 0,
#   'earnings management behaviour': 1,
#   'ethical orientation': 1,
#   'nan': 1,
#   'pressure': 1,
#   'professional commitment': 1},
#  {'': 0,
#   'development management': 1,
#   'higher education': 1,
#   'management model': 1,
#   'nan': 1,
#   'resource': 1,
#   'resource approach': 1},
#  {'': 0,
#   'developing country': 1,
#   'isomorphism': 1,
#   'mediation': 1,
#   'nan': 1,
#   'nigerium': 1,
#   'organizational culture': 1,
#   'voluntary disclosure': 1},
#  {'': 0,
#   'health network': 1,
#   'nan': 1,
#   'personalization': 1,
#   'psychic health at work': 1,
#   'socialisation': 1,
#   'transfer of experience': 1},
#  {'': 0,
#   'corporate ethics programme': 1,
#   'fraud detection': 1,
#   'giving voice to value': 1,
#   'moral reasoning': 1,
#   'nan': 1,
#   'organizational wrongdoing': 1,
#   'whistleblowing': 1},
#  {'': 0,
#   'accounting innovation': 1,
#   'actor network theory': 1,
#   'health organization': 1,
#   'nan': 1},
#  {'': 0,
#   'healthcare': 1,
#   'intellectual capital': 1,
#   'nan': 1,
#   'sustainable development': 1},
#  {'': 0,
#   'academic medical centre': 1,
#   'aged': 1,
#   'aged, 80 and over': 1,
#   'ageing': 1,
#   'article': 1,
#   'clinical evaluation': 1,
#   'communication barrier': 1,
#   'controlled study': 1,
#   'disparity': 1,
#   'english ': 1,
#   'female': 1,
#   'health care cost': 1,
#   'health care delivery': 1,
#   'health care quality': 1,
#   'hospital charge': 1,
#   'hospital readmission': 1,
#   'hospital running cost': 1,
#   'hospitalization': 1,
#   'human': 1,
#   'interpreter service': 1,
#   'intervention': 1,
#   'language': 1,
#   'language ability': 1,
#   'language access': 1,
#   'length of stay': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'middle aged': 1,
#   'organization and management': 1,
#   'outcome assessment': 1,
#   'patient readmission': 1,
#   'priority journal': 1,
#   'quality of care': 1,
#   'quality of health care': 1,
#   'quasi experimental study': 1,
#   'quasiexperimental design': 1,
#   'readmission': 1,
#   'russian ': 1,
#   'spanish ': 1,
#   'statistics and numerical datum': 1,
#   'telephone': 1,
#   'total quality management': 1,
#   'translating': 1,
#   'translating ': 1,
#   'underserved population': 1,
#   'united state': 1,
#   'university hospital': 1,
#   'very elderly': 1},
#  {'': 0,
#   'access': 1,
#   'accounting': 1,
#   'australium': 1,
#   'benchmark': 1,
#   'benchmarking': 1,
#   'catchment': 1,
#   'classification': 1,
#   'consultation': 1,
#   'cost': 1,
#   'doctor patient relation': 1,
#   'equity': 1,
#   'exercise': 1,
#   'human': 1,
#   'information processing': 1,
#   'pilot study': 1,
#   'population group': 1,
#   'population model': 1,
#   'population size': 1,
#   'primary care': 1,
#   'primary health care': 1,
#   'public health': 1,
#   'rural health': 1,
#   'rural population': 1,
#   'salary': 1,
#   'scientist': 1,
#   'statistic': 1},
#  {'': 0,
#   'bahrain': 1,
#   'compliance': 1,
#   'corporate governance': 1,
#   'disclosure': 1,
#   'ifr': 1,
#   'nan': 1},
#  {'': 0,
#   'adult': 1,
#   'affective disorder': 1,
#   'age': 1,
#   'aged': 1,
#   'article': 1,
#   'austrium': 1,
#   'autonomic dysfunction': 1,
#   'autonomic nervous system': 1,
#   'bioassay': 1,
#   'body mass': 1,
#   'burnout': 1,
#   'burnout, professional': 1,
#   'cardiovascular disease': 1,
#   'cardiovascular system': 1,
#   'chronic work stress': 1,
#   'demography': 1,
#   'depression': 1,
#   'disease association': 1,
#   'dresden': 1,
#   'emotional stress': 1,
#   'exhaustion': 1,
#   'fatigue': 1,
#   'female': 1,
#   'germany': 1,
#   'heart rate': 1,
#   'heart rate variability': 1,
#   'human': 1,
#   'job stress': 1,
#   'longitudinal study': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'mental health': 1,
#   'multiple linear regression analysis': 1,
#   'multiple regression': 1,
#   'nervous system': 1,
#   'occupational exposure': 1,
#   'pathophysiology': 1,
#   'physiology': 1,
#   'population research': 1,
#   'priority journal': 1,
#   'psychology': 1,
#   'questionnaire': 1,
#   'regulatory mechanism': 1,
#   'rest': 1,
#   'root mean square of successive difference': 1,
#   'saxony': 1,
#   'self report': 1,
#   'statistical analysis': 1,
#   'stress': 1,
#   'surveys and questionnaire': 1,
#   'switzerland': 1,
#   'symptom': 1,
#   'symptomatology': 1,
#   'vagal function': 1,
#   'vein puncture': 1,
#   'work stress': 1,
#   'working condition': 1,
#   'workplace': 1},
#  {'': 0,
#   'amenity': 1,
#   'australium': 1,
#   'catchment': 1,
#   'community': 1,
#   'correlation coefficient': 1,
#   'demography': 1,
#   'doctor patient relation': 1,
#   'doctor shortage': 1,
#   'economic': 1,
#   'environment': 1,
#   'general practitioner': 1,
#   'government': 1,
#   'health care delivery': 1,
#   'health care manpower': 1,
#   'health manpower': 1,
#   'health services accessibility': 1,
#   'housing': 1,
#   'human': 1,
#   'least square analysis': 1,
#   'manpower': 1,
#   'model': 1,
#   'multiple linear regression analysis': 1,
#   'organization and management': 1,
#   'physicians, primary care': 1,
#   'place attraction': 1,
#   'population size': 1,
#   'primary care': 1,
#   'primary health care': 1,
#   'recruitment and retention': 1,
#   'residence characteristic': 1,
#   'rural area': 1,
#   'rural health care': 1,
#   'rural health service': 1,
#   'rural population': 1,
#   'social isolation': 1,
#   'socioeconomic': 1,
#   'socioeconomic factor': 1,
#   'statistics and numerical datum': 1,
#   'supply and distribution': 1,
#   'united state': 1,
#   'usa': 1,
#   'workforce': 1},
#  {'': 0, 'aicpa': 1, 'disciplinary action': 1, 'nan': 1, 'sanction': 1},
#  {'': 0,
#   'attitude': 1,
#   'fraud triangle': 1,
#   'nan': 1,
#   'perceived control': 1,
#   'perceived norm': 1,
#   'theory of planned behaviour': 1,
#   'whistleblowing': 1},
#  {'': 0,
#   'factor analysis': 1,
#   'governance': 1,
#   'kenya': 1,
#   'nan': 1,
#   'principal component factor': 1,
#   'regulation': 1,
#   'savings and credit cooperative': 1,
#   'social disclosure': 1},
#  {'': 0,
#   'companys financial performance': 1,
#   'corporate social responsibility': 1,
#   'environmental responsibility': 1,
#   'nan': 1,
#   'sustainability': 1},
#  {'': 0,
#   'access to information': 1,
#   'article': 1,
#   'cardiovascular disease': 1,
#   'clinical trial': 1,
#   'computer security': 1,
#   'cooperation': 1,
#   'cooperative behaviour': 1,
#   'data base': 1,
#   'data mining': 1,
#   'delivery of health care, integrated': 1,
#   'familial hypercholesterolaemia studies collaboration': 1,
#   'familial hypercholesterolaemium': 1,
#   'familial hypercholesterolemium': 1,
#   'genetic': 1,
#   'human': 1,
#   'hyperlipoproteinemia type ii': 1,
#   'information dissemination': 1,
#   'information processing': 1,
#   'information retrieval': 1,
#   'information storage and retrieval': 1,
#   'integrated health care system': 1,
#   'international cooperation': 1,
#   'interpersonal communication': 1,
#   'ldl-cholesterol': 1,
#   'medical ethic': 1,
#   'medical information': 1,
#   'medical society': 1,
#   'methodology': 1,
#   'mortality': 1,
#   'multicenter study': 1,
#   'organization': 1,
#   'organization and management': 1,
#   'organizational objective': 1,
#   'patient care': 1,
#   'practise gap': 1,
#   'priority journal': 1,
#   'professional practise gap': 1,
#   'register': 1,
#   'registry': 1,
#   'research design': 1,
#   'study design': 1,
#   'treatment outcome': 1},
#  {'': 0,
#   'adult': 1,
#   'adulthood': 1,
#   'age': 1,
#   'aged': 1,
#   'alcohol': 1,
#   'alcohol consumption': 1,
#   'antineoplastic hormone agonists and antagonist': 1,
#   'article': 1,
#   'behavioural risk factor': 1,
#   'biopsy': 1,
#   'blood': 1,
#   'caloric intake': 1,
#   'cancer hormone therapy': 1,
#   'cancer incidence': 1,
#   'cancer radiotherapy': 1,
#   'cancer risk': 1,
#   'cancer screening': 1,
#   'cancer surgery': 1,
#   'cohort analysis': 1,
#   'cohort study': 1,
#   'controlled study': 1,
#   'ejaculation': 1,
#   'epidemiology': 1,
#   'erectile dysfunction': 1,
#   'follow up': 1,
#   'follow-up study': 1,
#   'frequency': 1,
#   'human': 1,
#   'human tissue': 1,
#   'incidence': 1,
#   'kallikrein': 1,
#   'kallikrein-related peptidase 3, human': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'middle aged': 1,
#   'multimodality cancer therapy': 1,
#   'pathology': 1,
#   'priority journal': 1,
#   'proportional hazards model': 1,
#   'prospective study': 1,
#   'prostate biopsy': 1,
#   'prostate cancer': 1,
#   'prostate specific antigen': 1,
#   'prostate tumor': 1,
#   'prostate-specific antigen': 1,
#   'prostatectomy': 1,
#   'prostatic neoplasm': 1,
#   'questionnaire': 1,
#   'risk': 1,
#   'risk factor': 1,
#   'united state': 1,
#   'young adult': 1},
#  {'': 0,
#   'ethical development': 1,
#   'ethics education framework ': 1,
#   'ethics integration': 1,
#   'nan': 1,
#   'uk accounting ethic': 1},
#  {'': 0,
#   'corporate governance asian country': 1,
#   'financial reporting': 1,
#   'forensic accounting': 1,
#   'forensic chartered accountant': 1,
#   'nan': 1,
#   'regulatory body': 1},
#  {'': 0,
#   'adult': 1,
#   'behaviour': 1,
#   'british columbium': 1,
#   'empowerment': 1,
#   'female': 1,
#   'health care organization': 1,
#   'human': 1,
#   'human experiment': 1,
#   'job satisfaction': 1,
#   'leadership': 1,
#   'male': 1,
#   'middle aged': 1,
#   'multiple regression': 1,
#   'nursing': 1,
#   'nursing management': 1,
#   'nursing staff': 1,
#   'nursing staff, hospital': 1,
#   'organization': 1,
#   'organizational culture': 1,
#   'patient care': 1,
#   'power ': 1,
#   'professional autonomy': 1,
#   'professional practise': 1,
#   'psychology': 1,
#   'questionnaire': 1,
#   'staff nurse': 1,
#   'structure activity relation': 1,
#   'surveys and questionnaire': 1,
#   'turnover time': 1,
#   'workplace': 1},
#  {'': 0,
#   'acetylsalicylic acid': 1,
#   'adult': 1,
#   'aged': 1,
#   'alpha tocopherol': 1,
#   'article': 1,
#   'body mass': 1,
#   'cancer risk': 1,
#   'chemoprevention': 1,
#   'chondroitin': 1,
#   'cohort analysis': 1,
#   'colorectal cancer': 1,
#   'controlled study': 1,
#   'dietary fiber': 1,
#   'dietary supplement': 1,
#   'disease association': 1,
#   'epidemiology': 1,
#   'female': 1,
#   'glucosamine': 1,
#   'human': 1,
#   'major clinical study': 1,
#   'male': 1,
#   'physical activity': 1,
#   'priority journal': 1,
#   'prospective study': 1,
#   'risk reduction': 1,
#   'sex difference': 1,
#   'treatment duration': 1,
#   'vitamin intake': 1},
#  {'': 0,
#   'angina, stable': 1,
#   'article': 1,
#   'asthma': 1,
#   'atrial fibrillation': 1,
#   'brazil': 1,
#   'chronic obstructive lung disease': 1,
#   'congestive heart failure': 1,
#   'controlled study': 1,
#   'coronary artery disease': 1,
#   'dementium': 1,
#   'depression': 1,
#   'diabetes mellitu': 1,
#   'gastroesophageal reflux': 1,
#   'health care personnel': 1,
#   'health care quality': 1,
#   'heart failure': 1,
#   'human': 1,
#   'hypercholesterolemium': 1,
#   'hypertension': 1,
#   'male': 1,
#   'nan': 1,
#   'non communicable disease': 1,
#   'osteoarthriti': 1,
#   'osteoporosi': 1,
#   'practise guideline': 1,
#   'practise guidelines as topic': 1,
#   'prostate hypertrophy': 1,
#   'prostatic hyperplasium': 1,
#   'pulmonary disease, chronic obstructive': 1,
#   'stable angina pectori': 1},
#  {'': 0,
#   'epidemiology': 1,
#   'knee injury': 1,
#   'nan': 1,
#   'return to sport': 1,
#   'sports injure': 1},
#  {'': 0,
#   'accreditation': 1,
#   'accreditation board for engineering and technology': 1,
#   'ate': 1,
#   'automatic test equipment': 1,
#   'automatic testing': 1,
#   'budget control': 1,
#   'built in test': 1,
#   'built-in test': 1,
#   'cost': 1,
#   'cost engineering': 1,
#   'curricula': 1,
#   'design for testability': 1,
#   'dft': 1,
#   'diagnostic': 1,
#   'education': 1,
#   'educational opportunity': 1,
#   'engineer': 1,
#   'engineering activity': 1,
#   'engineering curriculum': 1,
#   'engineering department': 1,
#   'engineering education': 1,
#   'equipment testing': 1,
#   'life cycle': 1,
#   'obsolescence': 1,
#   'personnel training': 1,
#   'plasma diagnostic': 1,
#   'postsecondary education': 1,
#   'professional aspect': 1,
#   'software testing': 1,
#   'student': 1,
#   'test': 1,
#   'testing': 1},
#  {'': 0,
#   'adult': 1,
#   'attitude': 1,
#   'attitude of health personnel': 1,
#   'clinical pharmacy service': 1,
#   'cross-sectional study': 1,
#   'female': 1,
#   'general hospital': 1,
#   'health personnel attitude': 1,
#   'hospital pharmacy': 1,
#   'hospitals, general': 1,
#   'human': 1,
#   'intention': 1,
#   'male': 1,
#   'middle aged': 1,
#   'models, theoretical': 1,
#   'organization and management': 1,
#   'patient care': 1,
#   'patient-centered care': 1,
#   'pharmacist': 1,
#   'pharmacy service, hospital': 1,
#   'procedure': 1,
#   'professional role': 1,
#   'professional standard': 1,
#   'psychology': 1,
#   'questionnaire': 1,
#   'statistics and numerical datum': 1,
#   'structural equation model': 1,
#   'surveys and questionnaire': 1,
#   'theoretical model': 1,
#   'theory of planned behaviour': 1},
#  {'': 0,
#   'charter management organization': 1,
#   'charter school': 1,
#   'leadership': 1,
#   'nan': 1,
#   'teacher turnover': 1,
#   'teacher workload': 1,
#   'urban education': 1,
#   'working condition': 1},
#  {'': 0,
#   'competency development': 1,
#   'nan': 1,
#   'process and outcome': 1,
#   'professional training': 1,
#   'psychosocial aspects of disability': 1,
#   'rehabilitation counselling': 1,
#   'rehabilitation counsellor': 1},
#  {'': 0,
#   'article': 1,
#   'human': 1,
#   'journalism': 1,
#   'knowledge': 1,
#   'mass medium': 1,
#   'practise guideline': 1,
#   'prevention': 1,
#   'public health service': 1,
#   'publishing': 1,
#   'qualitative analysis': 1,
#   'quantitative analysis': 1,
#   'statistics and numerical datum': 1,
#   'suicidal ideation': 1,
#   'suicide': 1},
#  {'': 0,
#   'building': 1,
#   'clinical practise': 1,
#   'confidentiality': 1,
#   'confidentiality/privacy': 1,
#   'dermatology': 1,
#   'disclosure': 1,
#   'doctor patient relation': 1,
#   'emergency medicine': 1,
#   'ethic': 1,
#   'ethics, clinical': 1,
#   'female': 1,
#   'gynecology': 1,
#   'health care personnel': 1,
#   'health personnel': 1,
#   'hospital organization': 1,
#   'human': 1,
#   'human experiment': 1,
#   'interpersonal communication': 1,
#   'male': 1,
#   'maxillofacial surgery': 1,
#   'medical ethic': 1,
#   'mental health': 1,
#   'nephrology': 1,
#   'neurology': 1,
#   'obstetric': 1,
#   'ophthalmology': 1,
#   'orthopedic': 1,
#   'paediatric': 1,
#   'physician': 1,
#   'privacy': 1,
#   'professional ethic': 1,
#   'professional-patient relation': 1,
#   'professional-patient relationship': 1,
#   'rheumatology': 1,
#   'student': 1,
#   'surgery': 1,
#   'tertiary care centre': 1,
#   'traumatology': 1,
#   'university': 1},
#  {'': 0,
#   'expectation': 1,
#   'generally accepted accounting principle': 1,
#   'health care organization': 1,
#   'human': 1,
#   'income': 1,
#   'international financial reporting standard': 1,
#   'law suit': 1,
#   'nan': 1,
#   'professional standard': 1,
# ...
#   'board of trustee': 1,
#   'commerce': 1,
#   'commercial phenomena': 1,
#   'decision making, organizational': 1,
#   'economic': 1,
#   'governing board': 1,
#   'human': 1,
#   'interprofessional relation': 1,
#   'investment': 1,
#   'leadership': 1,
#   'nan': 1,
#   'organization': 1,
#   'organization and management': 1,
#   'organizational culture': 1,
#   'professional competence': 1,
#   'public relation': 1,
#   'social behaviour': 1,
#   'social psychology': 1,
#   'social responsibility': 1,
#   'social value': 1,
#   'standard': 1},
#  {'': 0,
#   'competition': 1,
#   'cost accounting': 1,
#   'decision making': 1,
#   'education': 1,
#   'management accounting system': 1,
#   'nan': 1,
#   'product development': 1,
#   'professional aspect': 1,
#   'sale': 1,
#   'societies and institution': 1,
#   'throughput': 1,
#   'value added accounting': 1},
#  {'': 0,
#   'corporate ethical value': 1,
#   'ethical environment': 1,
#   'ethics code': 1,
#   'nan': 1},
#  {'': 0, 'code of ethic': 1, 'diversity': 1, 'nan': 1, 'social capital': 1},
#  {'': 0,
#   'history': 1,
#   'nan': 1,
#   'profession': 1,
#   'public sector accounting': 1},
#  {'': 0,
#   'certified public accountant': 1,
#   'chartered accountant': 1,
#   'code of professional conduct': 1,
#   'nan': 1},
#  {'': 0,
#   'accounting standard': 1,
#   'assets valuation': 1,
#   'depreciation': 1,
#   'existing use value': 1,
#   'nan': 1,
#   'valuation': 1,
#   'value\ue4f8in\ue4f8use pricing': 1},
#  {'': 0,
#   'accounting': 1,
#   'administrative personnel': 1,
#   'article': 1,
#   'consumer': 1,
#   'consumer satisfaction': 1,
#   'financial management': 1,
#   'financial management, hospital': 1,
#   'human': 1,
#   'income': 1,
#   'leadership': 1,
#   'methodology': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'patient credit and collection': 1,
#   'united state': 1},
#  {'': 0,
#   'accountant': 1,
#   'accounting firm': 1,
#   'group working': 1,
#   'job analysis': 1,
#   'learning': 1,
#   'nan': 1,
#   'staff turnover': 1},
#  {'': 0, 'employee': 1, 'human asset accounting': 1, 'loyalty': 1, 'nan': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'choice behaviour': 1,
#   'control': 1,
#   'decision making': 1,
#   'human': 1,
#   'internal-external control': 1,
#   'moral': 1,
#   'morality': 1,
#   'nan': 1,
#   'occupation': 1,
#   'social class': 1,
#   'social desirability': 1},
#  {'': 0,
#   'accounting firm marketing': 1,
#   'marketing role': 1,
#   'nan': 1,
#   'practise development': 1},
#  {'': 0,
#   'accounting': 1,
#   'accounts payable and receivable': 1,
#   'appointments and schedule': 1,
#   'article': 1,
#   'dental staff': 1,
#   'dentist': 1,
#   'economic': 1,
#   'hospital management': 1,
#   'human': 1,
#   'human relation': 1,
#   'management': 1,
#   'methodology': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'patient credit and collection': 1,
#   'practise management, dental': 1,
#   'professional-patient relation': 1,
#   'time management': 1},
#  {'': 0,
#   'corporate culture': 1,
#   'intangible asset': 1,
#   'intellectual capital': 1,
#   'nan': 1,
#   'value analysis': 1},
#  {'': 0,
#   'confidence': 1,
#   'derivatives market': 1,
#   'finance': 1,
#   'nan': 1,
#   'profession': 1},
#  {'': 0,
#   'cost management system': 1,
#   'electronic data interchange system': 1,
#   'information system effectiveness': 1,
#   'just-in-time manufacturing': 1,
#   'nan': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'board of trustee': 1,
#   'cost benefit analysis': 1,
#   'cost-benefit analysis': 1,
#   'economic': 1,
#   'efficiency, organizational': 1,
#   'financial audit': 1,
#   'governing board': 1,
#   'guideline': 1,
#   'hospital information system': 1,
#   'investment': 1,
#   'management': 1,
#   'management audit': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'ownership': 1,
#   'practise guideline': 1,
#   'professional role': 1,
#   'professional standard': 1,
#   'united state': 1},
#  {'': 0,
#   'accounting profession': 1,
#   'auditing profession': 1,
#   'belgium': 1,
#   'history': 1,
#   'nan': 1,
#   'professionalisation': 1},
#  {'': 0,
#   'article': 1,
#   'clinical medicine': 1,
#   'controlled study': 1,
#   'course': 1,
#   'education, medical': 1,
#   'environmental health': 1,
#   'environmental medicine': 1,
#   'general practitioner': 1,
#   'germany': 1,
#   'health': 1,
#   'health manpower': 1,
#   'historical development': 1,
#   'human': 1,
#   'hygiene': 1,
#   'institution': 1,
#   'medical research': 1,
#   'medical society': 1,
#   'multiple chemical sensitivity': 1,
#   'occupational medicine': 1,
#   'outpatient care': 1,
#   'primary medical care': 1,
#   'priority journal': 1,
#   'public health': 1,
#   'public health service': 1,
#   'public policy': 1,
#   'research': 1,
#   'research area': 1,
#   'retrospective study': 1,
#   'review for germany': 1,
#   'scientific community': 1,
#   'specialisation and further education': 1},
#  {'': 0,
#   'audit': 1,
#   'distance learning': 1,
#   'education': 1,
#   'nan': 1,
#   'undergraduate': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'dental staff': 1,
#   'dentist': 1,
#   'economic': 1,
#   'human': 1,
#   'human relation': 1,
#   'management': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'patient credit and collection': 1,
#   'practise management, dental': 1,
#   'professional-patient relation': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'attitude of health personnel': 1,
#   'budget': 1,
#   'decision making, organizational': 1,
#   'economic': 1,
#   'education': 1,
#   'great britain': 1,
#   'health personnel attitude': 1,
#   'hospitals, public': 1,
#   'human': 1,
#   'manpower': 1,
#   'nan': 1,
#   'national health service': 1,
#   'nurse administrator': 1,
#   'nurse attitude': 1,
#   'nurses role': 1,
#   'organization': 1,
#   'organization and management': 1,
#   'professional autonomy': 1,
#   'professional practise': 1,
#   'psychological aspect': 1,
#   'public hospital': 1,
#   'state medicine': 1,
#   'united kingdom': 1},
#  {'': 0,
#   'accounting': 1,
#   'international accounting standard': 1,
#   'nan': 1,
#   'property': 1,
#   'value': 1},
#  {'': 0,
#   'accounting': 1,
#   'american dietetic association': 1,
#   'article': 1,
#   'bioethics and professional ethic': 1,
#   'clinical practise': 1,
#   'conference paper': 1,
#   'conflict of interest': 1,
#   'decision making': 1,
#   'diet supplementation': 1,
#   'diet therapy': 1,
#   'dietary supplement': 1,
#   'dietetic': 1,
#   'economic': 1,
#   'ethic': 1,
#   'financial management': 1,
#   'health care organization': 1,
#   'health service': 1,
#   'human': 1,
#   'industry': 1,
#   'medicare': 1,
#   'nan': 1,
#   'nutrition therapy': 1,
#   'nutritional health': 1,
#   'professional misconduct': 1,
#   'risk assessment': 1,
#   'society': 1,
#   'united state': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'continuing education': 1,
#   'curriculum': 1,
#   'dental education': 1,
#   'education': 1,
#   'education, dental, graduate': 1,
#   'faculty, dental': 1,
#   'human': 1,
#   'management': 1,
#   'methodology': 1,
#   'motivation': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'orthodontic': 1,
#   'patient credit and collection': 1,
#   'planning technique': 1,
#   'practise management, dental': 1,
#   'professional practise': 1,
#   'review': 1,
#   'teaching': 1,
#   'writing': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'board of trustee': 1,
#   'chief executive officers, hospital': 1,
#   'economic': 1,
#   'efficiency, organizational': 1,
#   'financial audit': 1,
#   'governing board': 1,
#   'hospital administration': 1,
#   'hospital administrator': 1,
#   'hospital management': 1,
#   'leadership': 1,
#   'management': 1,
#   'management audit': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'professional competence': 1,
#   'social behaviour': 1,
#   'social responsibility': 1,
#   'standard': 1,
#   'united state': 1},
#  {'': 0,
#   'accounting': 1,
#   'administrative personnel': 1,
#   'article': 1,
#   'budget': 1,
#   'concept formation': 1,
#   'controlled study': 1,
#   'cost control': 1,
#   'curriculum': 1,
#   'dietetic': 1,
#   'dietitian': 1,
#   'economic': 1,
#   'financial management': 1,
#   'health care quality': 1,
#   'health education': 1,
#   'health programme': 1,
#   'health survey': 1,
#   'human': 1,
#   'medical practise': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'prescription': 1,
#   'professional competence': 1,
#   'questionnaire': 1,
#   'rating scale': 1,
#   'teaching': 1,
#   'university': 1},
#  {'': 0,
#   'nan': 1,
#   'organization-professional conflict': 1,
#   'organizational identification': 1,
#   'professional identification': 1,
#   'professional image': 1,
#   'turnover': 1},
#  {'': 0,
#   'credit card industry': 1,
#   'nan': 1,
#   'off-balance-sheet accounting issue': 1,
#   'securization': 1,
#   'sfas 91 & 105': 1},
#  {'': 0,
#   'accounting': 1,
#   'adult': 1,
#   'article': 1,
#   'capital financing': 1,
#   'demography': 1,
#   'dental equipment': 1,
#   'dental staff': 1,
#   'dentist': 1,
#   'economic': 1,
#   'education': 1,
#   'fee': 1,
#   'fees, dental': 1,
#   'female': 1,
#   'financial management': 1,
#   'human': 1,
#   'interprofessional relation': 1,
#   'leasing': 1,
#   'leasing, property': 1,
#   'male': 1,
#   'management': 1,
#   'methodology': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'patient': 1,
#   'practise management, dental': 1,
#   'practise valuation and purchase': 1,
#   'professional practise': 1,
#   'professional practise location': 1,
#   'public relation': 1,
#   'tax': 1,
#   'training support': 1},
#  {'': 0,
#   'article': 1,
#   'capitation fee': 1,
#   'health care delivery': 1,
#   'health care policy': 1,
#   'health maintenance organization': 1,
#   'home care': 1,
#   'hospital service': 1,
#   'managed care': 1,
#   'medical fee': 1,
#   'nan': 1,
#   'physician': 1,
#   'primary medical care': 1,
#   'responsibility': 1,
#   'risk management': 1},
#  {'': 0,
#   'audit qualification': 1,
#   'delay of annual and consolidated report': 1,
#   'delay of audit report': 1,
#   'french corporate reporting': 1,
#   'nan': 1,
#   'timeliness': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'cooperation': 1,
#   'health care management': 1,
#   'health care quality': 1,
#   'justice': 1,
#   'leadership': 1,
#   'medical ethic': 1,
#   'nan': 1,
#   'practise guideline': 1,
#   'priority journal': 1,
#   'professional practise': 1,
#   'survival': 1,
#   'teaching hospital': 1,
#   'university': 1},
#  {'': 0,
#   'article': 1,
#   'cost control': 1,
#   'decision making': 1,
#   'economic': 1,
#   'health care cost': 1,
#   'health care quality': 1,
#   'health care sector': 1,
#   'health insurance': 1,
#   'human': 1,
#   'institute of medicine ': 1,
#   'legal aspect': 1,
#   'legal liability': 1,
#   'liability, legal': 1,
#   'malpractice': 1,
#   'managed care programme': 1,
#   'medical error': 1,
#   'nan': 1,
#   'organization': 1,
#   'patient participation': 1,
#   'professional practise': 1,
#   'quality assurance, health care': 1,
#   'safety': 1,
#   'safety management': 1,
#   'standard': 1,
#   'united state': 1},
#  {'': 0,
#   'article': 1,
#   'economic': 1,
#   'efficiency, organizational': 1,
#   'health care cost': 1,
#   'health care organization': 1,
#   'health care policy': 1,
#   'health care rationing': 1,
#   'health care reform': 1,
#   'health care sector': 1,
#   'hospital administration': 1,
#   'hospital management': 1,
#   'hospital subdivisions and component': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'personnel administration, hospital': 1,
#   'politic': 1,
#   'professional autonomy': 1,
#   'professional practise': 1,
#   'reimbursement': 1,
#   'reimbursement mechanism': 1,
#   'standard': 1,
#   'total quality management': 1,
#   'uganda': 1,
#   'zambium': 1},
#  {'': 0,
#   'capital budgeting': 1,
#   'facility management': 1,
#   'nan': 1,
#   'planning': 1},
#  {'': 0,
#   'economic information': 1,
#   'embroidering': 1,
#   'embroidery': 1,
#   'nan': 1,
#   'retailing': 1},
#  {'': 0,
#   'africa': 1,
#   'best management practise': 1,
#   'capacity building': 1,
#   'development aid': 1,
#   'financial provision': 1,
#   'nan': 1},
#  {'': 0,
#   'health technology evaluation': 1,
#   'nan': 1,
#   'out patient surgery unit ': 1,
#   'outpatient surgery ': 1},
#  {'': 0,
#   'agricultural development': 1,
#   'agricultural policy': 1,
#   'modernization': 1,
#   'nan': 1,
#   'poland': 1,
#   'rural development': 1,
#   'socioeconomic condition': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'dental equipment': 1,
#   'dental facility': 1,
#   'dental office': 1,
#   'economic': 1,
#   'efficiency, organizational': 1,
#   'financial management': 1,
#   'human': 1,
#   'income': 1,
#   'management': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'practise management, dental': 1,
#   'practise valuation and purchase': 1,
#   'professional practise': 1,
#   'professional practise location': 1},
#  {'': 0,
#   'article': 1,
#   'breast cancer': 1,
#   'cancer staging': 1,
#   'cervix neoplasm': 1,
#   'conference paper': 1,
#   'delivery of health care': 1,
#   'education': 1,
#   'education, medical': 1,
#   'endometrial neoplasm': 1,
#   'endometrium cancer': 1,
#   'endometrium tumor': 1,
#   'female': 1,
#   'female genital tract tumor': 1,
#   'genital neoplasms, female': 1,
#   'gynecologic cancer': 1,
#   'gynecology': 1,
#   'health care delivery': 1,
#   'health care quality': 1,
#   'health care system': 1,
#   'human': 1,
#   'medical education': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'ovarian neoplasm': 1,
#   'ovary cancer': 1,
#   'ovary tumor': 1,
#   'patient care': 1,
#   'patient referral': 1,
#   'practise guideline': 1,
#   'priority journal': 1,
#   'quality of health care': 1,
#   'united state': 1,
#   'uterine cervix cancer': 1,
#   'uterine cervix tumor': 1},
#  {'': 0,
#   'accounting': 1,
#   'cost control': 1,
#   'financial audit': 1,
#   'financial management': 1,
#   'financial management, hospital': 1,
#   'health care organization': 1,
#   'health care policy': 1,
#   'health economic': 1,
#   'nan': 1,
#   'professional staff committee': 1,
#   'review': 1,
#   'social responsibility': 1,
#   'standard': 1,
#   'united state': 1},
#  {'': 0,
#   'asset pricing': 1,
#   'asset valuation': 1,
#   'benchmarking': 1,
#   'nan': 1,
#   'strategy property management': 1},
#  {'': 0,
#   'accounting information system': 1,
#   'computer-assisted auditing technique': 1,
#   'distributed object middleware': 1,
#   'edp auditing': 1,
#   'internet technology': 1,
#   'nan': 1,
#   'object-oriented technology': 1},
#  {'': 0, 'learning style': 1, 'management education': 1, 'nan': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'confidentiality': 1,
#   'economic': 1,
#   'ethics committees, research': 1,
#   'financial audit': 1,
#   'forgery': 1,
#   'fraud': 1,
#   'government regulation': 1,
#   'guideline adherence': 1,
#   'health insurance': 1,
#   'health insurance portability and accountability act': 1,
#   'health service': 1,
#   'health services administration': 1,
#   'hospital administrator': 1,
#   'legal aspect': 1,
#   'management': 1,
#   'management audit': 1,
#   'medical record': 1,
#   'medical record administrator': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'organizational policy': 1,
#   'policy': 1,
#   'practise guideline': 1,
#   'professional standard': 1,
#   'research': 1,
#   'risk management': 1,
#   'social behaviour': 1,
#   'social responsibility': 1,
#   'standard': 1,
#   'united state': 1},
#  {'': 0,
#   'accounting': 1,
#   'capitalization': 1,
#   'flexibility': 1,
#   'lease': 1,
#   'nan': 1,
#   'real estate': 1,
#   'strategy': 1},
#  {'': 0,
#   'administrative personnel': 1,
#   'article': 1,
#   'artificial intelligence': 1,
#   'brain ischemium': 1,
#   'cerebrovascular accident': 1,
#   'clinical practise guideline': 1,
#   'compliance ': 1,
#   'computer analysis': 1,
#   'computer supported co-operative work': 1,
#   'decision making': 1,
#   'decision support systems, clinical': 1,
#   'guideline compliance': 1,
#   'health care delivery': 1,
#   'health care management': 1,
#   'health plan implementation': 1,
#   'healthcare organisation': 1,
#   'human': 1,
#   'methodology': 1,
#   'model': 1,
#   'nomenclature': 1,
#   'patient care management': 1,
#   'practise guideline': 1,
#   'priority journal': 1,
#   'process control': 1,
#   'stroke': 1,
#   'workflow': 1},
#  {'': 0,
#   'accounting': 1,
#   'article': 1,
#   'decision making': 1,
#   'economic': 1,
#   'evaluation': 1,
#   'financial audit': 1,
#   'human': 1,
#   'insurance': 1,
#   'insurance carrier': 1,
#   'insurance coverage': 1,
#   'insurance, liability': 1,
#   'legal aspect': 1,
#   'malpractice': 1,
#   'management': 1,
#   'nan': 1,
#   'organization and management': 1,
#   'practise management, medical': 1,
#   'united state': 1},
#  ...]

# %%
len(dictlist)
# Out:
# 1229

# %%
#remove invalid dictionary entries
for dict in dictlist:
    dict.pop('', 0)
    dict.pop('nan', 1)

# %% [markdown]
# # Convert a list of dictionaries to one-hot vector

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
v = DictVectorizer(sparse=False)

# %%
verctorised = v.fit_transform(dictlist)

# %% [markdown]
# If save to csv: #np.savetxt(".csv", verctorised, delimiter=",") : Too large

# %%
np.savez_compressed('regularised', a=verctorised) #save to npz files

# %%
loaded = np.load('regularised.npz')['a']

# %%
np.array_equal(loaded,verctorised) # check whether loaded array is same as saved array
# Out:
# True

# %% [markdown]
# # Agglomerative Clustering

# %% [markdown]
# ## Prepare data and library

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
loaded = np.load('regularised.npz')['a'] #loaded vectorised data

# %%
np.array_equal(loaded,verctorised) # check only for the first time

# %% [markdown]
# ## Define algorithm

# %%
hierechycluster = AgglomerativeClustering(n_clusters=30, affinity='euclidean', 
                                            memory=None, connectivity=None, 
                                            compute_full_tree='auto', linkage='ward')

# %% [markdown]
# ## Run training

# %%
# %prun -l nmf.py hierechycluster.fit(loaded)

# %% [markdown]
# ## Save trained model

# %%
from sklearn.externals import joblib

# %%
joblib.dump(hierechycluster, 'agglomeraiveregularised30groups.pkl')
# Out:
# ['agglomeraiveregularised30groups.pkl']

# %% [markdown]
# ## The group label is in "hierechycluster.labels_ " now

# %%
len(hierechycluster.labels_) - len(processeddata) #test the length before combining
# Out:
# 0

# %% [markdown]
# # Build a new array for instance with rawmaterial and label ( "hierechycluster.labels_")

# %%
a = hierechycluster.labels_
a.resize((len(a), 1))

# %%
b = np.hstack((processeddata, a))

# %%
processingdata = processeddata.copy(deep=True)

# %%
processingdata['label'] = hierechycluster.labels_

# %%
processingdata
# Out:
#       Unnamed: 0                                            Authors  \
# 0              0                  Young J., Herath S.K., McCoy R.M.
# 1              1                             Aili C., Nilsson L.-E.
# 2              2                          Sandholzer M., Wouters M.
# 3              3                          Hwang Y., Lin H., Shin D.
# 4              4               Girella L., Tizzano R., Ferrari E.R.
# 5              5                Kinslow B., De Heer H.D., Warren M.
# 6              6                      Horton K.E., Wanderley C.D.A.
# 7              7       Bai Y., Li J., Bai Y., Ma W., Yang X., Ma F.
# 8              8                                Murphy B., Quinn M.
# 9              9             Persson M.E., Radcliffe V.S., Stein M.
# 10            10      Gold A., Klynsmit P., Wallage P., Wright A.M.
# 11            11  Gonzalez J.A., Ragins B.R., Ehrhardt K., Singh R.
# 12            12  Hamada T., Khalaf N., Yuan C., Babic A., Moral...
# 13            13      Jelihovschi A.P.G., Cardoso R.L., Linhares A.
# 14            14                               Vivian B., Maroun W.
# 15            15             Dzuranin A.C., Jones J.R., Olvera R.M.
# 16            16          Bahador K.M.K., Haider A., Saman W.S.W.M.
# 17            17                             Paisey C., Paisey N.J.
# 18            18                           Curtis M.B., Taylor E.Z.
# 19            19                                          Detzen D.
# 20            20                      Scafarto V., Dimitropoulos P.
# 21            21                 Donnelly S., Begley E., O’Brien M.
# 22            22           Tourtouras C., Kyridis A., Karamouzas N.
# 23            23                             Armaghan N., Renaud J.
# 24            24                                   García Torres D.
# 25            25                                          Dobija D.
# 26            26  Zhang J.-F., Yao Y.-Y., Xiong C.-R., Zhao S., ...
# 27            29   Guarnieri R., Grande M., Zuffetti F., Testori T.
# 28            30    Gao F., Kihal W., Meur N., Souris M., Deguen S.
# 29            31                Stoel M.D., Ballou B., Heitger D.L.
# ...          ...                                                ...
# 1199        1469                                        Crenshaw B.
# 1200        1471                                       Dillard J.F.
# 1201        1472                                       Dickson G.W.
# 1202        1475                           White Jr. A.R., Boyer F.
# 1203        1476              Rothberg D.L., Pinto J., Gertman P.M.
# 1204        1477                                  Ackerman Jr. F.K.
# 1205        1478                                      Reinecke K.P.
# 1206        1479                                         Stern A.R.
# 1207        1482               Westphal M., Frazier E., Miller M.C.
# 1208        1483         Carmichael Paul L., Carmichael Jr. Paul L.
# 1209        1484                                         Brown D.E.
# 1210        1485                                       Eresian J.G.
# 1211        1489                                         Allcorn S.
# 1212        1490                         [No author name available]
# 1213        1491                         [No author name available]
# 1214        1492                         [No author name available]
# 1215        1493                                       Newmark G.L.
# 1216        1494                          Matthews V.L., Feather J.
# 1217        1495                                        O'Connor P.
# 1218        1496                                          Oviatt W.
# 1219        1497                                        Khailany A.
# 1220        1498                      Lyall D., Perks R., Wright K.
# 1221        1499                                             Oie J.
# 1222        1501  Goldstein R.L., Roberts J.S., Stanton B.A., Ma...
# 1223        1502                                      Sanazaro P.J.
# 1224        1503                                        Parker L.D.
# 1225        1505                         Buck C.R., Jr., White K.L.
# 1226        1507                         [No author name available]
# 1227        1508                                    Halberstam M.J.
# 1228        1510                         [No author name available]
#
#                                                   Title  Year  \
# 0     Why not accounting and finance: An African Ame...  2018
# 1     Backstage accounting in preschool: analysing d...  2018
# 2     The history of the standard for the calculatio...  2018
# 3     Knowledge system commitment and knowledge shar...  2018
# 4     Concepts travelling across disciplinary fields...  2018
# 5     Few adults with functional limitations advised...  2018
# 6     Identity conflict and the paradox of embedded ...  2018
# 7     Development and validation of a questionnaire ...  2018
# 8     The emergence of mandatory continuing professi...  2018
# 9     Elmer G Beamer and the American Institute of C...  2018
# 10    The impact of the auditor selection process an...  2018
# 11    Friends and Family: The Role of Relationships ...  2018
# 12    Statin use and pancreatic cancer risk in two p...  2018
# 13    An analysis of the associations among cognitiv...  2018
# 14    Progressive public administration and new publ...  2018
# 15    Infusing data analytics into the accounting cu...  2018
# 16    Assessing information technology skills using ...  2018
# 17    Protecting the public interest? Continuing pro...  2018
# 18    Developmental mentoring, affective organizatio...  2018
# 19    A “New Deal” for the profession: Regulatory in...  2018
# 20    Human capital and financial performance in pro...  2018
# 21    How are people with dementia involved in care-...  2018
# 22    The Departments of Education in the maelstrom ...  2018
# 23    A conversational case-based reasoning approach...  2018
# 24    Distributed leadership and teacher job satisfa...  2018
# 25    The early evolution of corporate control and a...  2018
# 26    Establishment and application of quality contr...  2018
# 27    Incidence of peri-implant diseases on implants...  2018
# 28    Does the edge effect impact on the measure of ...  2017
# 29    The impact of quantitative versus qualitative ...  2017
# ...                                                 ...   ...
# 1199             PIER program solves internal problems.  1981
# 1200  AN UPDATE ON THE APPLICABILITY OF AN OCCUPATIO...  1981
# 1201  Management Information Systems: Evolution and ...  1981
# 1202  High risk financial committee reduces accounts...  1980
# 1203  Medicare utilization in the United States: PSR...  1980
# 1204                            Management peer review.  1980
# 1205  The journal "Stomatologiia" (Moskva)--The prof...  1980
# 1206                   Instilling activism in trustees.  1980
# 1207  Changes in average length of stay and average ...  1979
# 1208  IN-HOUSE COMPUTER SYSTEM FOR GENERAL OFFICE OP...  1979
# 1209             PSRO impact: are the statements valid?  1979
# 1210       The audit committee: watchdog for the board.  1979
# 1211                    Internal auditing for hospitals  1979
# 1212              HEW halts funding for Tennessee PSRO.  1978
# 1213            Hospital's work plan speeds up billing.  1978
# 1214                                 Cost of regulation  1978
# 1215  Reimbursement policies effective January 1, 1977.  1976
# 1216  Utilization of health services in western Cana...  1976
# 1217  Strong Vocational Interest Blank scores and di...  1976
# 1218  PSRO: a time to practice the techniques of cos...  1976
# 1219  An introductory COBOL course with structured p...  1976
# 1220    Create a state auditing board? Yes... No... yes  1976
# 1221                Hospital administration (Norwegian)  1976
# 1222  Data for peer review: acquisition and use. Res...  1975
# 1223                         Private Initiative in PSRO  1975
# 1224                 The accountant in the organisation  1975
# 1225  Peer Review: Impact of a System Based on Billi...  1974
# 1226  Report of the task force on medicaid and relat...  1972
# 1227  Liberal Thought, Radical Theory and Medical Pr...  1971
# 1228  White paper harms professionals and those they...  1970
#
#                                            Source title Volume  Issue  \
# 0                     Journal of Education for Business     93      4
# 1                             Ethnography and Education     13      2
# 2                                    Accounting History    NaN    NaN
# 3       International Journal of Information Management     39    NaN
# 4                  Journal of Management and Governance    NaN    NaN
# 5                     Physiotherapy Theory and Practice    NaN    NaN
# 6                        Management Accounting Research     38    NaN
# 7                          BMC Health Services Research     18      1
# 8                                    Accounting History     23  1-Feb
# 9                                    Accounting History     23  1-Feb
# 10                                             Auditing     37      1
# 11                   Journal of Business and Psychology     33      1
# 12                          Journal of Gastroenterology    NaN    NaN
# 13                              Frontiers in Psychology      8    JAN
# 14                        Meditari Accountancy Research     26      1
# 15                      Journal of Accounting Education    NaN    NaN
# 16          Journal of Engineering and Applied Sciences     13      4
# 17                  Critical Perspectives on Accounting    NaN    NaN
# 18                      Journal of Knowledge Management     22      1
# 19      Accounting, Auditing and Accountability Journal     31      3
# 20                       Corporate Governance (Bingley)     18      2
# 21                                             Dementia    NaN    NaN
# 22                                    Academia (Greece)    NaN     11
# 23                  Knowledge Management and E-Learning     10      1
# 24                Journal of Educational Administration     56      1
# 25      Accounting, Auditing and Accountability Journal     31      1
# 26           Chinese Journal of Schistosomiasis Control     30      1
# 27    International Journal of Oral and Maxillofacia...     33      2
# 28          International Journal of Health Geographics     16      1
# 29                                  Accounting Horizons     31      4
# ...                                                 ...    ...    ...
# 1199                               Hospital peer review      6      3
# 1200                                  Decision Sciences     12      1
# 1201                              Advances in Computers     20      C
# 1202                                          Hospitals     54     23
# 1203                           Health Services Research     15      3
# 1204                           Medical Group Management     27      5
# 1205                               Stomatologie der DDR     30      3
# 1206                            Harvard Business Review     58      1
# 1207                           Health Services Research     14      4
# 1208  Institution of Mechanical Engineers, Conferenc...    NaN    NaN
# 1209                            Quality Review Bulletin      5     10
# 1210                                            Trustee     32      3
# 1211                                                NaN    NaN    NaN
# 1212                              American medical news     21     41
# 1213                      Hospital financial management     32      9
# 1214                                                NaN    NaN    NaN
# 1215                                          Hospitals     50     24
# 1216               Canadian Medical Association Journal    114      4
# 1217                        Journal of dental education     40     11
# 1218                 The Investor-owned hospital review      9      1
# 1219  Proceedings of the ACM SIGCSE-SIGCUE Technical...    NaN    NaN
# 1220                                        Accountancy     87    994
# 1221            Tidsskrift for den Norske Laegeforening     96  19-21
# 1222                        Annals of Internal Medicine     82      2
# 1223                    New England Journal of Medicine    293     20
# 1224                               Accountants Magazine     79    826
# 1225                    New England Journal of Medicine    291     17
# 1226           Abstracts of Hospital Management Studies      9      3
# 1227                    New England Journal of Medicine    284     21
# 1228         Journal of the Canadian Dental Association     36      5
#
#      Art. No. Page start    Page end  ...    ISBN  CODEN   PubMed ID  \
# 0         NaN        165         171  ...     NaN    NaN         NaN
# 1         NaN        218         234  ...     NaN    NaN         NaN
# 2         NaN        NaN         NaN  ...     NaN    NaN         NaN
# 3         NaN        220         227  ...     NaN  IJMAE         NaN
# 4         NaN          1          30  ...     NaN    NaN         NaN
# 5         NaN          1           7  ...     NaN  PTHPE         NaN
# 6         NaN         39          50  ...     NaN    NaN         NaN
# 7         107        NaN         NaN  ...     NaN    NaN         NaN
# 8         NaN         93         116  ...     NaN    NaN         NaN
# 9         NaN         71          92  ...     NaN    NaN         NaN
# 10        NaN         69          87  ...     NaN    NaN         NaN
# 11        NaN         89         104  ...     NaN    NaN         NaN
# 12        NaN          1           8  ...     NaN  JOGAE         NaN
# 13       2324        NaN         NaN  ...     NaN    NaN         NaN
# 14        NaN         44          69  ...     NaN    NaN         NaN
# 15        NaN        NaN         NaN  ...     NaN    NaN         NaN
# 16        NaN        954         960  ...     NaN    NaN         NaN
# 17        NaN        NaN         NaN  ...     NaN    NaN         NaN
# 18        NaN        142         161  ...     NaN    NaN         NaN
# 19        NaN        970         992  ...     NaN    NaN         NaN
# 20        NaN        289         316  ...     NaN    NaN         NaN
# 21        NaN        NaN         NaN  ...     NaN    NaN         NaN
# 22        NaN        103         121  ...     NaN    NaN         NaN
# 23        NaN         53          66  ...     NaN    NaN         NaN
# 24        NaN        127         142  ...     NaN    NaN         NaN
# 25        NaN        214         236  ...     NaN    NaN         NaN
# 26        NaN         26          31  ...     NaN    NaN         NaN
# 27        NaN        457         465  ...     NaN    NaN         NaN
# 28         46        NaN         NaN  ...     NaN    NaN         NaN
# 29        NaN         53          69  ...     NaN    NaN         NaN
# ...       ...        ...         ...  ...     ...    ...         ...
# 1199      NaN         33          34  ...     NaN    NaN  10250116.0
# 1200      NaN         32          38  ...     NaN    NaN         NaN
# 1201      NaN          1          37  ...     NaN    NaN         NaN
# 1202      NaN        NaN         NaN  ...     NaN    NaN   7429454.0
# 1203      NaN        249         270  ...     NaN  HESRA   7009497.0
# 1204      NaN         28          30  ...     NaN    NaN  10248367.0
# 1205      NaN        219         225  ...     NaN    NaN   6932134.0
# 1206      NaN         24  26, 28, 32  ...     NaN    NaN  10245408.0
# 1207      NaN        253         265  ...     NaN  HESRA    393658.0
# 1208      NaN        733         736  ...     NaN    NaN         NaN
# 1209      NaN         12          14  ...     NaN    NaN    121381.0
# 1210      NaN         43  45, 47, 49  ...     NaN    NaN  10240721.0
# 1211      NaN        NaN         NaN  ...     NaN    NaN         NaN
# 1212      NaN        NaN         NaN  ...     NaN    NaN  10273096.0
# 1213      NaN         48         NaN  ...     NaN    NaN  10308275.0
# 1214      NaN        NaN         NaN  ...     NaN    NaN         NaN
# 1215      NaN         39          46  ...     NaN    NaN   1033142.0
# 1216      NaN        309         312  ...     NaN  CMAJA   1253067.0
# 1217      NaN        733         739  ...     NaN    NaN   1068150.0
# 1218      NaN         45         NaN  ...     NaN    NaN  10273147.0
# 1219      NaN         11          16  ...     NaN    NaN         NaN
# 1220      NaN         34          37  ...     NaN  ACTYA         NaN
# 1221      NaN       1056        1058  ...     NaN  TNLAA    968825.0
# 1222      NaN        262         267  ...     NaN  AIMEA   1167772.0
# 1223      NaN       1023        1028  ...     NaN    NaN   1237088.0
# 1224      NaN        149         152  ...     NaN  ACMGA         NaN
# 1225      NaN        877         883  ...     NaN    NaN   4606894.0
# 1226      NaN       9195       130p.  ...     NaN  XXXXX         NaN
# 1227      NaN       1180        1185  ...     NaN    NaN   5572481.0
# 1228      NaN        173         174  ...     NaN    NaN   5268139.0
#
#      Language of Original Document  \
# 0                          English
# 1                          English
# 2                          English
# 3                          English
# 4                          English
# 5                          English
# 6                          English
# 7                          English
# 8                          English
# 9                          English
# 10                         English
# 11                         English
# 12                         English
# 13                         English
# 14                         English
# 15                         English
# 16                         English
# 17                         English
# 18                         English
# 19                         English
# 20                         English
# 21                         English
# 22                           Greek
# 23                         English
# 24                         English
# 25                         English
# 26                         Chinese
# 27                         English
# 28                         English
# 29                         English
# ...                            ...
# 1199                       English
# 1200                       English
# 1201                       English
# 1202                       English
# 1203                       English
# 1204                       English
# 1205                        German
# 1206                       English
# 1207                       English
# 1208                           NaN
# 1209                       English
# 1210                       English
# 1211                       English
# 1212                       English
# 1213                       English
# 1214                       English
# 1215                       English
# 1216                       English
# 1217                       English
# 1218                       English
# 1219                       English
# 1220                       English
# 1221                     Norwegian
# 1222                       English
# 1223                       English
# 1224                       English
# 1225                       English
# 1226                       English
# 1227                       English
# 1228                       English
#
#                                Abbreviated Source Title     Document Type  \
# 0                                          J. Edu. Bus.           Article
# 1                                        Ethnogr. Educ.           Article
# 2                                        Account. Hist.  Article in Press
# 3                                      Int J Inf Manage           Article
# 4                                       J. Manage. Gov.  Article in Press
# 5                             Physiother. Theory Pract.  Article in Press
# 6                                 Manage. Account. Res.           Article
# 7                                 BMC Health Serv. Res.           Article
# 8                                        Account. Hist.           Article
# 9                                        Account. Hist.           Article
# 10                                             Auditing           Article
# 11                                     J. Bus. Psychol.           Article
# 12                                    J. Gastroenterol.  Article in Press
# 13                                      Front. Psychol.           Article
# 14                               Meditari Account. Res.           Article
# 15                                    J. Account. Educ.  Article in Press
# 16                                   J. Eng. Appl. Sci.           Article
# 17                             Crit. Perspect. Account.  Article in Press
# 18                                     J. Knowl. Manag.           Article
# 19                          Account. Audit. Account. J.           Article
# 20                                           Corp. Gov.           Article
# 21                                             Dementia  Article in Press
# 22                                                Acad.           Article
# 23                              Knowl. Manage. E-Learn.           Article
# 24                                        J. Educ. Adm.           Article
# 25                          Account. Audit. Account. J.           Article
# 26                     Chin. J. Schistosomiasis Control           Article
# 27                    Int. J. Oral Maxillofac. Implants           Article
# 28                                Int. J. Health Geogr.           Article
# 29                                      Account. Horiz.           Article
# ...                                                 ...               ...
# 1199                                      Hosp Peer Rev           Article
# 1200                                        Decis. Sci.           Article
# 1201                                       Adv. Comput.           Article
# 1202                                          Hospitals           Article
# 1203                                  HEALTH SERV. RES.           Article
# 1204                                   Med Group Manage           Article
# 1205                                       Stomatol DDR           Article
# 1206                                       Harv Bus Rev           Article
# 1207                                  HEALTH SERV. RES.           Article
# 1208                                                NaN               NaN
# 1209                                  QRB Qual Rev Bull           Article
# 1210                                            Trustee           Article
# 1211                                                NaN           Article
# 1212                                        Am Med News           Article
# 1213                                 Hosp Financ Manage           Article
# 1214                                                NaN           Article
# 1215                                          Hospitals           Article
# 1216                                CAN. MED. ASSOC. J.           Article
# 1217                                        J Dent Educ           Article
# 1218                            Investor Owned Hosp Rev           Article
# 1219  Proc. ACM SIGCSE-SIGCUE Tech. Symp. Comput. Sc...  Conference Paper
# 1220                                        ACCOUNTANCY           Article
# 1221                          TIDSSKR. NOR. LAEGEFOREN.           Article
# 1222                                  ANN. INTERN. MED.           Article
# 1223                                  New Engl. J. Med.           Article
# 1224                                      ACCOUNT. MAG.           Article
# 1225                                  New Engl. J. Med.           Article
# 1226                            ABSTR.HOSP.MANAGE.STUD.           Article
# 1227                                  New Engl. J. Med.           Article
# 1228                                   J Can Dent Assoc           Article
#
#      Access Type  Source                 EID  label
# 0            NaN  Scopus  2-s2.0-85044462722     15
# 1            NaN  Scopus  2-s2.0-85018843303     15
# 2            NaN  Scopus  2-s2.0-85045146460     15
# 3            NaN  Scopus  2-s2.0-85039744212      7
# 4            NaN  Scopus  2-s2.0-85043688733     20
# 5            NaN  Scopus  2-s2.0-85042907106      1
# 6            NaN  Scopus  2-s2.0-85009774798     15
# 7            NaN  Scopus  2-s2.0-85042027900     26
# 8            NaN  Scopus  2-s2.0-85044140728     15
# 9            NaN  Scopus  2-s2.0-85043692705     15
# 10           NaN  Scopus  2-s2.0-85041716185     15
# 11           NaN  Scopus  2-s2.0-84990911109     15
# 12           NaN  Scopus  2-s2.0-85040862060     15
# 13           NaN  Scopus  2-s2.0-85040529589     15
# 14           NaN  Scopus  2-s2.0-85045623770     15
# 15           NaN  Scopus  2-s2.0-85045578419     15
# 16           NaN  Scopus  2-s2.0-85044476893      7
# 17           NaN  Scopus  2-s2.0-85046115758     15
# 18           NaN  Scopus  2-s2.0-85044067257     15
# 19           NaN  Scopus  2-s2.0-85044314677     15
# 20           NaN  Scopus  2-s2.0-85039866485     15
# 21           NaN  Scopus  2-s2.0-85044034273     15
# 22           NaN  Scopus  2-s2.0-85040745835     15
# 23           NaN  Scopus  2-s2.0-85044320321     15
# 24           NaN  Scopus  2-s2.0-85036527627     15
# 25           NaN  Scopus  2-s2.0-85041716351     15
# 26           NaN  Scopus  2-s2.0-85043709312     26
# 27           NaN  Scopus  2-s2.0-85045000866     15
# 28           NaN  Scopus  2-s2.0-85037717121     15
# 29           NaN  Scopus  2-s2.0-85036634061     15
# ...          ...     ...                 ...    ...
# 1199         NaN  Scopus   2-s2.0-0019544288      9
# 1200         NaN  Scopus  2-s2.0-84989405929     15
# 1201         NaN  Scopus   2-s2.0-0020494879     15
# 1202         NaN  Scopus   2-s2.0-0019244110      9
# 1203         NaN  Scopus   2-s2.0-0019287466      9
# 1204         NaN  Scopus   2-s2.0-0019056463      9
# 1205         NaN  Scopus   2-s2.0-0018991652     20
# 1206         NaN  Scopus   2-s2.0-0018845405     26
# 1207         NaN  Scopus   2-s2.0-0018567193      9
# 1208         NaN  Scopus   2-s2.0-0018752724     15
# 1209         NaN  Scopus   2-s2.0-0018528495      9
# 1210         NaN  Scopus   2-s2.0-0018442158      9
# 1211         NaN  Scopus  2-s2.0-85040276943     15
# 1212         NaN  Scopus   2-s2.0-0018273792      9
# 1213         NaN  Scopus   2-s2.0-0018010817      9
# 1214         NaN  Scopus  2-s2.0-85040204868     15
# 1215         NaN  Scopus   2-s2.0-0017309298      9
# 1216         NaN  Scopus   2-s2.0-0017234104     20
# 1217         NaN  Scopus   2-s2.0-0017022305     26
# 1218         NaN  Scopus   2-s2.0-0016922613      9
# 1219         NaN  Scopus  2-s2.0-85033480947      7
# 1220         NaN  Scopus   2-s2.0-0017082498     20
# 1221         NaN  Scopus   2-s2.0-0017127715     20
# 1222         NaN  Scopus   2-s2.0-0016661303      9
# 1223         NaN  Scopus   2-s2.0-0016780326      7
# 1224         NaN  Scopus   2-s2.0-0016632253      7
# 1225         NaN  Scopus   2-s2.0-0016297778     20
# 1226         NaN  Scopus  2-s2.0-18544403619     15
# 1227         NaN  Scopus   2-s2.0-0015242181      3
# 1228         NaN  Scopus   2-s2.0-0014783962     20
#
# [1229 rows x 43 columns]

# %%
processingdata.to_csv('labelled300groups.csv')

# %% [markdown]
# # Group Analysing

# %%
def statistic(akey,ekey,materiality):

    fdict={}
    returndict = {}
    keythreshold = materiality * len(akey)
    #Fill the list with dictionaries
    for i in range(1,len(akey)):

        singledict = {}
#        if akey.values[i] != 'NaN' and akey.values[i] != 'nan':
        for keywordsingle in str(akey.values[i]).split(';'):

            processedkeyword = regularise(keywordsingle)

            singledict[processedkeyword] = 1     

#        if ekey.values[i] != 'NaN' and ekey.values[i] != 'nan':
        for keywordsingle in str(ekey.values[i]).split(';'):

            processedkeyword = regularise(keywordsingle)

            singledict[processedkeyword] = 1     


        for key in singledict:
            if key in fdict:
                fdict[key] = fdict[key] + 1
            else:
                fdict[key] = 1
                
    if 'nan' in fdict: fdict.pop('nan')
    
    if 'NaN' in fdict: fdict.pop('NaN')
    
    for key in fdict:
        if fdict[key] > keythreshold:
            returndict[key] = fdict[key]
    
    return returndict

# %%
def checkpart(group, materiality):
    

    selectedpart = processingdata.loc[processingdata['label'] == group]

    authkey = selectedpart.iloc[:,17]
    editkey = selectedpart.iloc[:,18]
    
    dictforreturn = statistic(authkey,editkey,materiality)
    
    return dictforreturn, len(selectedpart)

# %%
isolatedgroup = 0
monstergroup = 0

isolatedlist = []
monsterlist = []

for i in range(0,30):
     

    
    
    groupkeyword, groupsize = checkpart(i,0.3)
    
    if groupsize <= 5: 
        isolatedgroup = isolatedgroup + 1
        isolatedlist.append(groupsize)
    elif groupsize >= 400: 
        monstergroup = monstergroup + 1
        monsterlist.append(groupsize)
        print('GROUP',i,'Size',groupsize) 
        print (groupkeyword)
    else:
        print('GROUP',i,'Size',groupsize) 
        print (groupkeyword)
        
print ('isolatedgroup',isolatedgroup)

print (isolatedlist)


print ('monstergroup', monstergroup)

print (monsterlist)
# Out:
# GROUP 0 Size 7
# {'female': 5, 'united state': 5, 'body mass index': 4, 'logistic model': 4, 'body mass': 5, 'male': 4, 'obesity': 5, 'human': 6, 'article': 5, 'statistical model': 3, 'cross-sectional study': 3, 'risk': 3, 'risk factor': 3, 'statistic': 3}
# GROUP 1 Size 58
# {'human': 57, 'middle aged': 27, 'article': 46, 'female': 44, 'adult': 43, 'questionnaire': 21, 'male': 48}
# GROUP 2 Size 19
# {'health care delivery': 6, 'human': 14, 'health care organization': 11, 'review': 15, 'accounting': 14, 'united state': 12, 'financial management': 8}
# GROUP 3 Size 18
# {'health care delivery': 12, 'human': 10, 'reimbursement': 6, 'article': 16, 'economic': 9, 'united state': 7, 'financial management': 8, 'delivery of health care': 12, 'health care policy': 8, 'health care cost': 9, 'organization and management': 15}
# GROUP 5 Size 10
# {'major clinical study': 5, 'prospective study': 5, 'body weight': 4, 'adult': 9, 'female': 7, 'cohort analysis': 5, 'aged': 5, 'body mass': 6, 'obesity': 6, 'male': 7, 'human': 9, 'article': 9, 'controlled study': 8, 'body mass index': 4, 'weight gain': 4, 'priority journal': 5, 'physical activity': 5, 'risk factor': 4, 'middle aged': 6}
# GROUP 7 Size 126
# {'professional aspect': 48, 'cost accounting': 56}
# GROUP 8 Size 9
# {'middle aged': 6, 'adult': 5, 'female': 8, 'patient education': 3, 'male': 8, 'major clinical study': 3, 'human': 8, 'article': 8, 'controlled study': 5, 'statistics and numerical datum': 6, 'priority journal': 4, 'organization and management': 6, 'medical education': 3}
# GROUP 9 Size 69
# {'human': 26, 'article': 58, 'accounting': 61, 'united state': 55, 'financial management': 24, 'economic': 35, 'patient credit and collection': 21, 'organization and management': 41}
# GROUP 10 Size 27
# {'human': 21, 'priority journal': 20, 'article': 9}
# GROUP 13 Size 8
# {'workload': 3, 'attitude of health personnel': 3, 'middle aged': 5, 'nursing staff, hospital': 4, 'female': 7, 'united state': 3, 'job satisfaction': 6, 'nursing staff': 4, 'psychological aspect': 3, 'male': 7, 'human': 7, 'article': 3, 'organization': 4, 'psychology': 3, 'health personnel attitude': 3, 'adult': 6, 'organization and management': 4, 'organizational culture': 4}
# GROUP 14 Size 17
# {'human': 16, 'questionnaire': 6, 'article': 12, 'female': 6, 'patient care': 8, 'health personnel attitude': 13, 'decision making': 7, 'organization and management': 14, 'attitude of health personnel': 14, 'psychological aspect': 6}
# GROUP 15 Size 584
# {}
# GROUP 16 Size 28
# {'human': 21, 'management': 12, 'article': 25, 'professional practise': 16, 'accounting': 25, 'practise management, dental': 10, 'organization': 12, 'financial management': 15, 'economic': 22, 'organization and management': 25, 'personnel management': 9}
# GROUP 17 Size 18
# {'economic': 11, 'standard': 8, 'board of trustee': 11, 'professional standard': 13, 'professional competence': 6, 'united state': 16, 'social responsibility': 8, 'governing board': 11, 'hospital administrator': 6, 'professional role': 9, 'management': 8, 'article': 17, 'organization': 9, 'accounting': 17, 'organizational objective': 6, 'management audit': 8, 'social behaviour': 8, 'financial management': 6, 'financial audit': 13, 'organization and management': 13}
# GROUP 20 Size 72
# {'accounting': 60}
# GROUP 21 Size 19
# {'human': 9, 'management': 6, 'methodology': 7, 'economic aspect': 15, 'accounting': 13, 'united state': 8, 'financial management, hospital': 8, 'financial management': 10, 'organization and management': 16, 'short survey': 17, 'hospital': 7}
# GROUP 26 Size 96
# {'human': 86, 'organization and management': 46, 'article': 65}
# GROUP 29 Size 16
# {'interpersonal communication': 5, 'methodology': 7, 'practise management, dental': 10, 'patient credit and collection': 14, 'dental staff': 9, 'management': 11, 'human': 15, 'communication': 5, 'professional-patient relation': 15, 'dentist': 9, 'accounting': 15, 'economic': 12, 'human relation': 15, 'article': 15, 'financial management': 8, 'organization and management': 14}
# isolatedgroup 12
# [4, 4, 1, 5, 1, 1, 2, 1, 1, 3, 1, 4]
# monstergroup 1
# [584]
